# %% [markdown]
# # Statistical Language Modeling with NLTK

# %% [markdown]
# ### Recommended Reading
#
# - Dan Jurafsky and James H. Martin's __Speech and Language Processing__ ([3rd ed. draft](https://web.stanford.edu/~jurafsky/slp3/))

# %% [markdown]
# ### Covered Material
# - SLP
#     - [Chapter 3: N-gram Language Models](https://web.stanford.edu/~jurafsky/slp3/3.pdf)

# %% [markdown]
# ### Requirements
#
# - [NLTK](https://www.nltk.org/)

# %% [markdown]
# ## 1. Ngrams and Ngram Counting

# %% [markdown]
# [n-gram](https://en.wikipedia.org/wiki/N-gram) is a contiguous sequence of *n* items from a given sequence of text or speech. An n-gram model models sequences, notably natural languages, using the statistical properties of n-grams.
#
# __Example__:
#
# - character n-grams: mice
# - word n-grams: the answer is 42
#
#
# |                     | 1-gram  | 2-gram  | 3-gram  |
# |---------------------|---------|---------|---------|
# |                     | unigram | bigram  | trigram |
# | *Markov Order*      | 0       | 1       | 2       |
# | *Character N-grams* | `['m', 'i', 'c', 'e']` | `['mi', 'ic', 'ce']` | `['mic', 'ice']` |
# | *Word N-grams*      | `['the', 'answer', 'is' , '42']` | `['the answer', 'answer is', ...]` | `['the answer is', ...]` |

# %% [markdown]
# ### 1.1. Counting Ngrams
#
# *Frequency List* of a corpus is essentially a unigram count. Ngram count only differs in a unit of counting sequence of $n$ of tokens.
#
# We can compute the count by taking sequences of 2 items (bigrams), 3 items (trigrams), etc.

# %% [markdown]
# #### 1.1.1. Preparing Data
# The required data format for ngram counting is a _list-of-lists_ (lists of sentences consisting of lists of words):
#
# ```
# [
#      ['the', 'answer', 'is', '42'],
#      ['the', 'mice', 'said']
# ]
# ```

# %% [markdown]
# #### 1.1.2. Sentence beginning & end tags
#
# >Including sentence boundary markers leads to a better model. To do that we need to augment each sentence with a special symbols for beginning and end of sentence tags (`<s>` and `</s>`, respectively). The beginning of the sentence (BOS) tag gives the bigram context of the first word; and encodes probability of a word to start a sentence. Adding the end of the sentence (EOS) tag, on the other hand, makes the bigram model a true probability distribution (Jurafsky and Martin). "Without it,  the sentence probabilities for all sentences of *a given length* would sum to one only. This model would define an infinite set of probability distributions, with one distribution per sentence length"
#
# >For larger ngrams, we’ll need to assume extra context for the contexts to the left and right of the sentence boundaries. For example, to compute trigram probabilities at the very beginning of the sentence, we can use two pseudo-words for the first trigram (i.e. `['<s>', '<s>', w1]`). Alternatively, we can use [back-off](https://en.wikipedia.org/wiki/Katz%27s_back-off_model), and use the `['<s>', w1]` bigram probability.

# %% [markdown]
# **Example**:
# `['<s>', 'the', 'answer', 'is', '42', '</s>']`

# %% [markdown]
# #### 1.1.3. NLTK Utility Functions
# NLTK provides utility functions for padding sequences.

# %%
sent = ['the', 'answer', 'is', '42']

# %%
from nltk.util import pad_sequence

list(pad_sequence(
        sent,  # input sequence
        pad_left=True,
        left_pad_symbol="<s>",
        pad_right=True,
        right_pad_symbol="</s>",
        n=2  # padding for bigrams
    )
)

# %% [markdown]
# Another NLTK function wraps this utility function with default arguments to provide a more convenient interface.

# %%
from nltk.lm.preprocessing import pad_both_ends

list(pad_both_ends(sent, n=2))

# %% [markdown]
# #### 1.1.4. Extracting Ngrams
# NLTK provides a function to extact ngrams from a sequence, which also performs padding, if required arguments are provided.

# %%
from nltk.util import ngrams

list(ngrams(sent, 2))

# %%
bigrams = ngrams(
    sent,
    2,
    pad_left=True,
    left_pad_symbol="<s>",
    pad_right=True,
    right_pad_symbol="</s>",
)
list(bigrams)

# %% [markdown]
# Additionally, NLTK provides wrapper functions to extract bigrams and trigrams.

# %%
from nltk.util import bigrams, trigrams

print(list(bigrams(sent)))
print(list(trigrams(sent)))

print(list(bigrams(pad_both_ends(sent, n=2))))
print(list(bigrams(sent, 
                   pad_left=True, 
                   left_pad_symbol="<s>", 
                   pad_right=True, 
                   right_pad_symbol="</s>")))

# %% [markdown]
# #### 1.1.5. Extracting "Everygrams"
# To make an ngram model more robust, it is usually also trained on lower-ngrams (i.e. unigrams in case of bigrams).
# NLTK also provides utility function to extract these together.
#
# Note the `max_len` argument that defines the maximum length of an ngram.

# %%
from nltk.util import everygrams

print(list(everygrams(sent, max_len=2)))
print(list(everygrams(pad_both_ends(sent, n=2), max_len=2)))
# Out:
# [('t',), ('t', 'h'), ('h',), ('h', 'e'), ('e',), ('e', ' '), (' ',), (' ', 'k'), ('k',), ('k', 'i'), ('i',), ('i', 'n'), ('n',), ('n', 'g'), ('g',), ('g', ' '), (' ',), (' ', 'i'), ('i',), ('i', 's'), ('s',), ('s', ' '), (' ',), (' ', 'd'), ('d',), ('d', 'e'), ('e',), ('e', 'a'), ('a',), ('a', 'd'), ('d',)]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-724c89218f46> in <module>
#       2
#       3 print(list(everygrams(sent, max_len=2)))
# ----> 4 print(list(everygrams(pad_both_ends(sent, n=2), max_len=2)))
#
# NameError: name 'pad_both_ends' is not defined

# %%
all_ngrams = everygrams(
    sent,
    min_len=1,
    max_len=2,
    pad_left=True,
    left_pad_symbol="<s>",
    pad_right=True,
    right_pad_symbol="</s>"
)
list(all_ngrams)

# %% [markdown]
# #### 1.1.6. "Flattening" the Data
# For language model training and evaluation (as well as vocabulary extraction) NLTK expects the data to be a flat list.
# In python, this is accomplished either by using `itertools.chain.from_iterable` or python list comprehension as
#
# `[element for sublist in superlist for element in sublist]`

# %%
from itertools import chain

data = [['which', 'is', 'the', 'sense', 'of', 'life', '?'], ['the', 'answer', 'is', '42'] ]

list(chain.from_iterable(data))

# %%
# Comprehension list
[token for sent in data for token in sent]

# %%
from nltk.lm.preprocessing import flatten
list(flatten(data))
# Out:
# ['[',
#  'the',
#  'tragedie',
#  'of',
#  'hamlet',
#  'by',
#  'william',
#  'shakespeare',
#  '1599',
#  ']',
#  'actus',
#  'primus',
#  '.',
#  'scoena',
#  'prima',
#  '.',
#  'enter',
#  'barnardo',
#  'and',
#  'francisco',
#  'two',
#  'centinels',
#  '.',
#  'barnardo',
#  '.',
#  'who',
#  "'",
#  's',
#  'there',
#  '?',
#  'fran',
#  '.',
#  'nay',
#  'answer',
#  'me',
#  ':',
#  'stand',
#  '&',
#  'vnfold',
#  'your',
#  'selfe',
#  'bar',
#  '.',
#  'long',
#  'liue',
#  'the',
#  'king',
#  'fran',
#  '.',
#  'barnardo',
#  '?',
#  'bar',
#  '.',
#  'he',
#  'fran',
#  '.',
#  'you',
#  'come',
#  'most',
#  'carefully',
#  'vpon',
#  'your',
#  'houre',
#  'bar',
#  '.',
#  "'",
#  'tis',
#  'now',
#  'strook',
#  'twelue',
#  ',',
#  'get',
#  'thee',
#  'to',
#  'bed',
#  'francisco',
#  'fran',
#  '.',
#  'for',
#  'this',
#  'releefe',
#  'much',
#  'thankes',
#  ':',
#  "'",
#  'tis',
#  'bitter',
#  'cold',
#  ',',
#  'and',
#  'i',
#  'am',
#  'sicke',
#  'at',
#  'heart',
#  'barn',
#  '.',
#  'haue',
#  'you',
#  'had',
#  'quiet',
#  'guard',
#  '?',
#  'fran',
#  '.',
#  'not',
#  'a',
#  'mouse',
#  'stirring',
#  'barn',
#  '.',
#  'well',
#  ',',
#  'goodnight',
#  '.',
#  'if',
#  'you',
#  'do',
#  'meet',
#  'horatio',
#  'and',
#  'marcellus',
#  ',',
#  'the',
#  'riuals',
#  'of',
#  'my',
#  'watch',
#  ',',
#  'bid',
#  'them',
#  'make',
#  'hast',
#  '.',
#  'enter',
#  'horatio',
#  'and',
#  'marcellus',
#  '.',
#  'fran',
#  '.',
#  'i',
#  'thinke',
#  'i',
#  'heare',
#  'them',
#  '.',
#  'stand',
#  ':',
#  'who',
#  "'",
#  's',
#  'there',
#  '?',
#  'hor',
#  '.',
#  'friends',
#  'to',
#  'this',
#  'ground',
#  'mar',
#  '.',
#  'and',
#  'leige',
#  '-',
#  'men',
#  'to',
#  'the',
#  'dane',
#  'fran',
#  '.',
#  'giue',
#  'you',
#  'good',
#  'night',
#  'mar',
#  '.',
#  'o',
#  'farwel',
#  'honest',
#  'soldier',
#  ',',
#  'who',
#  'hath',
#  'relieu',
#  "'",
#  'd',
#  'you',
#  '?',
#  'fra',
#  '.',
#  'barnardo',
#  'ha',
#  "'",
#  's',
#  'my',
#  'place',
#  ':',
#  'giue',
#  'you',
#  'goodnight',
#  '.',
#  'exit',
#  'fran',
#  '.',
#  'mar',
#  '.',
#  'holla',
#  'barnardo',
#  'bar',
#  '.',
#  'say',
#  ',',
#  'what',
#  'is',
#  'horatio',
#  'there',
#  '?',
#  'hor',
#  '.',
#  'a',
#  'peece',
#  'of',
#  'him',
#  'bar',
#  '.',
#  'welcome',
#  'horatio',
#  ',',
#  'welcome',
#  'good',
#  'marcellus',
#  'mar',
#  '.',
#  'what',
#  ',',
#  'ha',
#  "'",
#  's',
#  'this',
#  'thing',
#  'appear',
#  "'",
#  'd',
#  'againe',
#  'to',
#  'night',
#  'bar',
#  '.',
#  'i',
#  'haue',
#  'seene',
#  'nothing',
#  'mar',
#  '.',
#  'horatio',
#  'saies',
#  ',',
#  "'",
#  'tis',
#  'but',
#  'our',
#  'fantasie',
#  ',',
#  'and',
#  'will',
#  'not',
#  'let',
#  'beleefe',
#  'take',
#  'hold',
#  'of',
#  'him',
#  'touching',
#  'this',
#  'dreaded',
#  'sight',
#  ',',
#  'twice',
#  'seene',
#  'of',
#  'vs',
#  ',',
#  'therefore',
#  'i',
#  'haue',
#  'intreated',
#  'him',
#  'along',
#  'with',
#  'vs',
#  ',',
#  'to',
#  'watch',
#  'the',
#  'minutes',
#  'of',
#  'this',
#  'night',
#  ',',
#  'that',
#  'if',
#  'againe',
#  'this',
#  'apparition',
#  'come',
#  ',',
#  'he',
#  'may',
#  'approue',
#  'our',
#  'eyes',
#  ',',
#  'and',
#  'speake',
#  'to',
#  'it',
#  'hor',
#  '.',
#  'tush',
#  ',',
#  'tush',
#  ',',
#  "'",
#  'twill',
#  'not',
#  'appeare',
#  'bar',
#  '.',
#  'sit',
#  'downe',
#  'a',
#  '-',
#  'while',
#  ',',
#  'and',
#  'let',
#  'vs',
#  'once',
#  'againe',
#  'assaile',
#  'your',
#  'eares',
#  ',',
#  'that',
#  'are',
#  'so',
#  'fortified',
#  'against',
#  'our',
#  'story',
#  ',',
#  'what',
#  'we',
#  'two',
#  'nights',
#  'haue',
#  'seene',
#  'hor',
#  '.',
#  'well',
#  ',',
#  'sit',
#  'we',
#  'downe',
#  ',',
#  'and',
#  'let',
#  'vs',
#  'heare',
#  'barnardo',
#  'speake',
#  'of',
#  'this',
#  'barn',
#  '.',
#  'last',
#  'night',
#  'of',
#  'all',
#  ',',
#  'when',
#  'yond',
#  'same',
#  'starre',
#  'that',
#  "'",
#  's',
#  'westward',
#  'from',
#  'the',
#  'pole',
#  'had',
#  'made',
#  'his',
#  'course',
#  't',
#  "'",
#  'illume',
#  'that',
#  'part',
#  'of',
#  'heauen',
#  'where',
#  'now',
#  'it',
#  'burnes',
#  ',',
#  'marcellus',
#  'and',
#  'my',
#  'selfe',
#  ',',
#  'the',
#  'bell',
#  'then',
#  'beating',
#  'one',
#  'mar',
#  '.',
#  'peace',
#  ',',
#  'breake',
#  'thee',
#  'of',
#  ':',
#  'enter',
#  'the',
#  'ghost',
#  '.',
#  'looke',
#  'where',
#  'it',
#  'comes',
#  'againe',
#  'barn',
#  '.',
#  'in',
#  'the',
#  'same',
#  'figure',
#  ',',
#  'like',
#  'the',
#  'king',
#  'that',
#  "'",
#  's',
#  'dead',
#  'mar',
#  '.',
#  'thou',
#  'art',
#  'a',
#  'scholler',
#  ';',
#  'speake',
#  'to',
#  'it',
#  'horatio',
#  'barn',
#  '.',
#  'lookes',
#  'it',
#  'not',
#  'like',
#  'the',
#  'king',
#  '?',
#  'marke',
#  'it',
#  'horatio',
#  'hora',
#  '.',
#  'most',
#  'like',
#  ':',
#  'it',
#  'harrowes',
#  'me',
#  'with',
#  'fear',
#  '&',
#  'wonder',
#  'barn',
#  '.',
#  'it',
#  'would',
#  'be',
#  'spoke',
#  'too',
#  'mar',
#  '.',
#  'question',
#  'it',
#  'horatio',
#  'hor',
#  '.',
#  'what',
#  'art',
#  'thou',
#  'that',
#  'vsurp',
#  "'",
#  'st',
#  'this',
#  'time',
#  'of',
#  'night',
#  ',',
#  'together',
#  'with',
#  'that',
#  'faire',
#  'and',
#  'warlike',
#  'forme',
#  'in',
#  'which',
#  'the',
#  'maiesty',
#  'of',
#  'buried',
#  'denmarke',
#  'did',
#  'sometimes',
#  'march',
#  ':',
#  'by',
#  'heauen',
#  'i',
#  'charge',
#  'thee',
#  'speake',
#  'mar',
#  '.',
#  'it',
#  'is',
#  'offended',
#  'barn',
#  '.',
#  'see',
#  ',',
#  'it',
#  'stalkes',
#  'away',
#  'hor',
#  '.',
#  'stay',
#  ':',
#  'speake',
#  ';',
#  'speake',
#  ':',
#  'i',
#  'charge',
#  'thee',
#  ',',
#  'speake',
#  '.',
#  'exit',
#  'the',
#  'ghost',
#  '.',
#  'mar',
#  '.',
#  "'",
#  'tis',
#  'gone',
#  ',',
#  'and',
#  'will',
#  'not',
#  'answer',
#  'barn',
#  '.',
#  'how',
#  'now',
#  'horatio',
#  '?',
#  'you',
#  'tremble',
#  '&',
#  'look',
#  'pale',
#  ':',
#  'is',
#  'not',
#  'this',
#  'something',
#  'more',
#  'then',
#  'fantasie',
#  '?',
#  'what',
#  'thinke',
#  'you',
#  'on',
#  "'",
#  't',
#  '?',
#  'hor',
#  '.',
#  'before',
#  'my',
#  'god',
#  ',',
#  'i',
#  'might',
#  'not',
#  'this',
#  'beleeue',
#  'without',
#  'the',
#  'sensible',
#  'and',
#  'true',
#  'auouch',
#  'of',
#  'mine',
#  'owne',
#  'eyes',
#  'mar',
#  '.',
#  'is',
#  'it',
#  'not',
#  'like',
#  'the',
#  'king',
#  '?',
#  'hor',
#  '.',
#  'as',
#  'thou',
#  'art',
#  'to',
#  'thy',
#  'selfe',
#  ',',
#  'such',
#  'was',
#  'the',
#  'very',
#  'armour',
#  'he',
#  'had',
#  'on',
#  ',',
#  'when',
#  'th',
#  "'",
#  'ambitious',
#  'norwey',
#  'combatted',
#  ':',
#  'so',
#  'frown',
#  "'",
#  'd',
#  'he',
#  'once',
#  ',',
#  'when',
#  'in',
#  'an',
#  'angry',
#  'parle',
#  'he',
#  'smot',
#  'the',
#  'sledded',
#  'pollax',
#  'on',
#  'the',
#  'ice',
#  '.',
#  "'",
#  'tis',
#  'strange',
#  'mar',
#  '.',
#  'thus',
#  'twice',
#  'before',
#  ',',
#  'and',
#  'iust',
#  'at',
#  'this',
#  'dead',
#  'houre',
#  ',',
#  'with',
#  'martiall',
#  'stalke',
#  ',',
#  'hath',
#  'he',
#  'gone',
#  'by',
#  'our',
#  'watch',
#  'hor',
#  '.',
#  'in',
#  'what',
#  'particular',
#  'thought',
#  'to',
#  'work',
#  ',',
#  'i',
#  'know',
#  'not',
#  ':',
#  'but',
#  'in',
#  'the',
#  'grosse',
#  'and',
#  'scope',
#  'of',
#  'my',
#  'opinion',
#  ',',
#  'this',
#  'boades',
#  'some',
#  'strange',
#  'erruption',
#  'to',
#  'our',
#  'state',
#  'mar',
#  '.',
#  'good',
#  'now',
#  'sit',
#  'downe',
#  ',',
#  '&',
#  'tell',
#  'me',
#  'he',
#  'that',
#  'knowes',
#  'why',
#  'this',
#  'same',
#  'strict',
#  'and',
#  'most',
#  'obseruant',
#  'watch',
#  ',',
#  'so',
#  'nightly',
#  'toyles',
#  'the',
#  'subiect',
#  'of',
#  'the',
#  'land',
#  ',',
#  'and',
#  'why',
#  'such',
#  'dayly',
#  'cast',
#  'of',
#  'brazon',
#  'cannon',
#  'and',
#  'forraigne',
#  'mart',
#  'for',
#  'implements',
#  'of',
#  'warre',
#  ':',
#  'why',
#  'such',
#  'impresse',
#  'of',
#  'ship',
#  '-',
#  'wrights',
#  ',',
#  'whose',
#  'sore',
#  'taske',
#  'do',
#  "'",
#  's',
#  'not',
#  'diuide',
#  'the',
#  'sunday',
#  'from',
#  'the',
#  'weeke',
#  ',',
#  'what',
#  'might',
#  'be',
#  'toward',
#  ',',
#  'that',
#  'this',
#  'sweaty',
#  'hast',
#  'doth',
#  'make',
#  'the',
#  'night',
#  'ioynt',
#  '-',
#  'labourer',
#  'with',
#  'the',
#  'day',
#  ':',
#  'who',
#  'is',
#  "'",
#  't',
#  'that',
#  'can',
#  'informe',
#  'me',
#  '?',
#  'hor',
#  '.',
#  'that',
#  'can',
#  'i',
#  ',',
#  'at',
#  'least',
#  'the',
#  'whisper',
#  'goes',
#  'so',
#  ':',
#  'our',
#  'last',
#  'king',
#  ',',
#  'whose',
#  'image',
#  'euen',
#  'but',
#  'now',
#  'appear',
#  "'",
#  'd',
#  'to',
#  'vs',
#  ',',
#  'was',
#  '(',
#  'as',
#  'you',
#  'know',
#  ')',
#  'by',
#  'fortinbras',
#  'of',
#  'norway',
#  ',',
#  '(',
#  'thereto',
#  'prick',
#  "'",
#  'd',
#  'on',
#  'by',
#  'a',
#  'most',
#  'emulate',
#  'pride',
#  ')',
#  'dar',
#  "'",
#  'd',
#  'to',
#  'the',
#  'combate',
#  '.',
#  'in',
#  'which',
#  ',',
#  'our',
#  'valiant',
#  'hamlet',
#  ',',
#  '(',
#  'for',
#  'so',
#  'this',
#  'side',
#  'of',
#  'our',
#  'knowne',
#  'world',
#  'esteem',
#  "'",
#  'd',
#  'him',
#  ')',
#  'did',
#  'slay',
#  'this',
#  'fortinbras',
#  ':',
#  'who',
#  'by',
#  'a',
#  'seal',
#  "'",
#  'd',
#  'compact',
#  ',',
#  'well',
#  'ratified',
#  'by',
#  'law',
#  ',',
#  'and',
#  'heraldrie',
#  ',',
#  'did',
#  'forfeite',
#  '(',
#  'with',
#  'his',
#  'life',
#  ')',
#  'all',
#  'those',
#  'his',
#  'lands',
#  'which',
#  'he',
#  'stood',
#  'seiz',
#  "'",
#  'd',
#  'on',
#  ',',
#  'to',
#  'the',
#  'conqueror',
#  ':',
#  'against',
#  'the',
#  'which',
#  ',',
#  'a',
#  'moity',
#  'competent',
#  'was',
#  'gaged',
#  'by',
#  'our',
#  'king',
#  ':',
#  'which',
#  'had',
#  'return',
#  "'",
#  'd',
#  'to',
#  'the',
#  'inheritance',
#  'of',
#  'fortinbras',
#  ',',
#  'had',
#  'he',
#  'bin',
#  'vanquisher',
#  ',',
#  'as',
#  'by',
#  'the',
#  'same',
#  'cou',
#  "'",
#  'nant',
#  'and',
#  'carriage',
#  'of',
#  'the',
#  'article',
#  'designe',
#  ',',
#  'his',
#  'fell',
#  ...]

# %% [markdown]
# #### 1.1.7. Combining the Tasks
# NLTK wraps both tasks:
#
# - padded ngram (everygram) extraction from each sentence
# - flat list creation
#
# into a convenient utility function `padded_everygram_pipeline` that returns lazy iterators.

# %%
from nltk.lm.preprocessing import padded_everygram_pipeline

padded_ngrams, flat_text = padded_everygram_pipeline(2, data)

# %%
for sent_ngrams in padded_ngrams:
    print(list(sent_ngrams))
# Out:
# [('<s>',), ('<s>', '['), ('[',), ('[', 'the'), ('the',), ('the', 'tragedie'), ('tragedie',), ('tragedie', 'of'), ('of',), ('of', 'hamlet'), ('hamlet',), ('hamlet', 'by'), ('by',), ('by', 'william'), ('william',), ('william', 'shakespeare'), ('shakespeare',), ('shakespeare', '1599'), ('1599',), ('1599', ']'), (']',), (']', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'actus'), ('actus',), ('actus', 'primus'), ('primus',), ('primus', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'scoena'), ('scoena',), ('scoena', 'prima'), ('prima',), ('prima', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'enter'), ('enter',), ('enter', 'barnardo'), ('barnardo',), ('barnardo', 'and'), ('and',), ('and', 'francisco'), ('francisco',), ('francisco', 'two'), ('two',), ('two', 'centinels'), ('centinels',), ('centinels', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barnardo'), ('barnardo',), ('barnardo', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'who'), ('who',), ('who', "'"), ("'",), ("'", 's'), ('s',), ('s', 'there'), ('there',), ('there', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'fran'), ('fran',), ('fran', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'nay'), ('nay',), ('nay', 'answer'), ('answer',), ('answer', 'me'), ('me',), ('me', ':'), (':',), (':', 'stand'), ('stand',), ('stand', '&'), ('&',), ('&', 'vnfold'), ('vnfold',), ('vnfold', 'your'), ('your',), ('your', 'selfe'), ('selfe',), ('selfe', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'bar'), ('bar',), ('bar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'long'), ('long',), ('long', 'liue'), ('liue',), ('liue', 'the'), ('the',), ('the', 'king'), ('king',), ('king', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'fran'), ('fran',), ('fran', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barnardo'), ('barnardo',), ('barnardo', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'bar'), ('bar',), ('bar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'he'), ('he',), ('he', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'fran'), ('fran',), ('fran', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'you'), ('you',), ('you', 'come'), ('come',), ('come', 'most'), ('most',), ('most', 'carefully'), ('carefully',), ('carefully', 'vpon'), ('vpon',), ('vpon', 'your'), ('your',), ('your', 'houre'), ('houre',), ('houre', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'bar'), ('bar',), ('bar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', "'"), ("'",), ("'", 'tis'), ('tis',), ('tis', 'now'), ('now',), ('now', 'strook'), ('strook',), ('strook', 'twelue'), ('twelue',), ('twelue', ','), (',',), (',', 'get'), ('get',), ('get', 'thee'), ('thee',), ('thee', 'to'), ('to',), ('to', 'bed'), ('bed',), ('bed', 'francisco'), ('francisco',), ('francisco', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'fran'), ('fran',), ('fran', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'for'), ('for',), ('for', 'this'), ('this',), ('this', 'releefe'), ('releefe',), ('releefe', 'much'), ('much',), ('much', 'thankes'), ('thankes',), ('thankes', ':'), (':',), (':', "'"), ("'",), ("'", 'tis'), ('tis',), ('tis', 'bitter'), ('bitter',), ('bitter', 'cold'), ('cold',), ('cold', ','), (',',), (',', 'and'), ('and',), ('and', 'i'), ('i',), ('i', 'am'), ('am',), ('am', 'sicke'), ('sicke',), ('sicke', 'at'), ('at',), ('at', 'heart'), ('heart',), ('heart', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barn'), ('barn',), ('barn', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'haue'), ('haue',), ('haue', 'you'), ('you',), ('you', 'had'), ('had',), ('had', 'quiet'), ('quiet',), ('quiet', 'guard'), ('guard',), ('guard', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'fran'), ('fran',), ('fran', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'not'), ('not',), ('not', 'a'), ('a',), ('a', 'mouse'), ('mouse',), ('mouse', 'stirring'), ('stirring',), ('stirring', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barn'), ('barn',), ('barn', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'well'), ('well',), ('well', ','), (',',), (',', 'goodnight'), ('goodnight',), ('goodnight', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'if'), ('if',), ('if', 'you'), ('you',), ('you', 'do'), ('do',), ('do', 'meet'), ('meet',), ('meet', 'horatio'), ('horatio',), ('horatio', 'and'), ('and',), ('and', 'marcellus'), ('marcellus',), ('marcellus', ','), (',',), (',', 'the'), ('the',), ('the', 'riuals'), ('riuals',), ('riuals', 'of'), ('of',), ('of', 'my'), ('my',), ('my', 'watch'), ('watch',), ('watch', ','), (',',), (',', 'bid'), ('bid',), ('bid', 'them'), ('them',), ('them', 'make'), ('make',), ('make', 'hast'), ('hast',), ('hast', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'enter'), ('enter',), ('enter', 'horatio'), ('horatio',), ('horatio', 'and'), ('and',), ('and', 'marcellus'), ('marcellus',), ('marcellus', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'fran'), ('fran',), ('fran', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'i'), ('i',), ('i', 'thinke'), ('thinke',), ('thinke', 'i'), ('i',), ('i', 'heare'), ('heare',), ('heare', 'them'), ('them',), ('them', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'stand'), ('stand',), ('stand', ':'), (':',), (':', 'who'), ('who',), ('who', "'"), ("'",), ("'", 's'), ('s',), ('s', 'there'), ('there',), ('there', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'friends'), ('friends',), ('friends', 'to'), ('to',), ('to', 'this'), ('this',), ('this', 'ground'), ('ground',), ('ground', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'and'), ('and',), ('and', 'leige'), ('leige',), ('leige', '-'), ('-',), ('-', 'men'), ('men',), ('men', 'to'), ('to',), ('to', 'the'), ('the',), ('the', 'dane'), ('dane',), ('dane', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'fran'), ('fran',), ('fran', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'giue'), ('giue',), ('giue', 'you'), ('you',), ('you', 'good'), ('good',), ('good', 'night'), ('night',), ('night', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'o'), ('o',), ('o', 'farwel'), ('farwel',), ('farwel', 'honest'), ('honest',), ('honest', 'soldier'), ('soldier',), ('soldier', ','), (',',), (',', 'who'), ('who',), ('who', 'hath'), ('hath',), ('hath', 'relieu'), ('relieu',), ('relieu', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'you'), ('you',), ('you', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'fra'), ('fra',), ('fra', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barnardo'), ('barnardo',), ('barnardo', 'ha'), ('ha',), ('ha', "'"), ("'",), ("'", 's'), ('s',), ('s', 'my'), ('my',), ('my', 'place'), ('place',), ('place', ':'), (':',), (':', 'giue'), ('giue',), ('giue', 'you'), ('you',), ('you', 'goodnight'), ('goodnight',), ('goodnight', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'exit'), ('exit',), ('exit', 'fran'), ('fran',), ('fran', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'holla'), ('holla',), ('holla', 'barnardo'), ('barnardo',), ('barnardo', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'bar'), ('bar',), ('bar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'say'), ('say',), ('say', ','), (',',), (',', 'what'), ('what',), ('what', 'is'), ('is',), ('is', 'horatio'), ('horatio',), ('horatio', 'there'), ('there',), ('there', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'a'), ('a',), ('a', 'peece'), ('peece',), ('peece', 'of'), ('of',), ('of', 'him'), ('him',), ('him', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'bar'), ('bar',), ('bar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'welcome'), ('welcome',), ('welcome', 'horatio'), ('horatio',), ('horatio', ','), (',',), (',', 'welcome'), ('welcome',), ('welcome', 'good'), ('good',), ('good', 'marcellus'), ('marcellus',), ('marcellus', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'what'), ('what',), ('what', ','), (',',), (',', 'ha'), ('ha',), ('ha', "'"), ("'",), ("'", 's'), ('s',), ('s', 'this'), ('this',), ('this', 'thing'), ('thing',), ('thing', 'appear'), ('appear',), ('appear', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'againe'), ('againe',), ('againe', 'to'), ('to',), ('to', 'night'), ('night',), ('night', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'bar'), ('bar',), ('bar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'i'), ('i',), ('i', 'haue'), ('haue',), ('haue', 'seene'), ('seene',), ('seene', 'nothing'), ('nothing',), ('nothing', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'horatio'), ('horatio',), ('horatio', 'saies'), ('saies',), ('saies', ','), (',',), (',', "'"), ("'",), ("'", 'tis'), ('tis',), ('tis', 'but'), ('but',), ('but', 'our'), ('our',), ('our', 'fantasie'), ('fantasie',), ('fantasie', ','), (',',), (',', 'and'), ('and',), ('and', 'will'), ('will',), ('will', 'not'), ('not',), ('not', 'let'), ('let',), ('let', 'beleefe'), ('beleefe',), ('beleefe', 'take'), ('take',), ('take', 'hold'), ('hold',), ('hold', 'of'), ('of',), ('of', 'him'), ('him',), ('him', 'touching'), ('touching',), ('touching', 'this'), ('this',), ('this', 'dreaded'), ('dreaded',), ('dreaded', 'sight'), ('sight',), ('sight', ','), (',',), (',', 'twice'), ('twice',), ('twice', 'seene'), ('seene',), ('seene', 'of'), ('of',), ('of', 'vs'), ('vs',), ('vs', ','), (',',), (',', 'therefore'), ('therefore',), ('therefore', 'i'), ('i',), ('i', 'haue'), ('haue',), ('haue', 'intreated'), ('intreated',), ('intreated', 'him'), ('him',), ('him', 'along'), ('along',), ('along', 'with'), ('with',), ('with', 'vs'), ('vs',), ('vs', ','), (',',), (',', 'to'), ('to',), ('to', 'watch'), ('watch',), ('watch', 'the'), ('the',), ('the', 'minutes'), ('minutes',), ('minutes', 'of'), ('of',), ('of', 'this'), ('this',), ('this', 'night'), ('night',), ('night', ','), (',',), (',', 'that'), ('that',), ('that', 'if'), ('if',), ('if', 'againe'), ('againe',), ('againe', 'this'), ('this',), ('this', 'apparition'), ('apparition',), ('apparition', 'come'), ('come',), ('come', ','), (',',), (',', 'he'), ('he',), ('he', 'may'), ('may',), ('may', 'approue'), ('approue',), ('approue', 'our'), ('our',), ('our', 'eyes'), ('eyes',), ('eyes', ','), (',',), (',', 'and'), ('and',), ('and', 'speake'), ('speake',), ('speake', 'to'), ('to',), ('to', 'it'), ('it',), ('it', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'tush'), ('tush',), ('tush', ','), (',',), (',', 'tush'), ('tush',), ('tush', ','), (',',), (',', "'"), ("'",), ("'", 'twill'), ('twill',), ('twill', 'not'), ('not',), ('not', 'appeare'), ('appeare',), ('appeare', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'bar'), ('bar',), ('bar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'sit'), ('sit',), ('sit', 'downe'), ('downe',), ('downe', 'a'), ('a',), ('a', '-'), ('-',), ('-', 'while'), ('while',), ('while', ','), (',',), (',', 'and'), ('and',), ('and', 'let'), ('let',), ('let', 'vs'), ('vs',), ('vs', 'once'), ('once',), ('once', 'againe'), ('againe',), ('againe', 'assaile'), ('assaile',), ('assaile', 'your'), ('your',), ('your', 'eares'), ('eares',), ('eares', ','), (',',), (',', 'that'), ('that',), ('that', 'are'), ('are',), ('are', 'so'), ('so',), ('so', 'fortified'), ('fortified',), ('fortified', 'against'), ('against',), ('against', 'our'), ('our',), ('our', 'story'), ('story',), ('story', ','), (',',), (',', 'what'), ('what',), ('what', 'we'), ('we',), ('we', 'two'), ('two',), ('two', 'nights'), ('nights',), ('nights', 'haue'), ('haue',), ('haue', 'seene'), ('seene',), ('seene', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'well'), ('well',), ('well', ','), (',',), (',', 'sit'), ('sit',), ('sit', 'we'), ('we',), ('we', 'downe'), ('downe',), ('downe', ','), (',',), (',', 'and'), ('and',), ('and', 'let'), ('let',), ('let', 'vs'), ('vs',), ('vs', 'heare'), ('heare',), ('heare', 'barnardo'), ('barnardo',), ('barnardo', 'speake'), ('speake',), ('speake', 'of'), ('of',), ('of', 'this'), ('this',), ('this', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barn'), ('barn',), ('barn', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'last'), ('last',), ('last', 'night'), ('night',), ('night', 'of'), ('of',), ('of', 'all'), ('all',), ('all', ','), (',',), (',', 'when'), ('when',), ('when', 'yond'), ('yond',), ('yond', 'same'), ('same',), ('same', 'starre'), ('starre',), ('starre', 'that'), ('that',), ('that', "'"), ("'",), ("'", 's'), ('s',), ('s', 'westward'), ('westward',), ('westward', 'from'), ('from',), ('from', 'the'), ('the',), ('the', 'pole'), ('pole',), ('pole', 'had'), ('had',), ('had', 'made'), ('made',), ('made', 'his'), ('his',), ('his', 'course'), ('course',), ('course', 't'), ('t',), ('t', "'"), ("'",), ("'", 'illume'), ('illume',), ('illume', 'that'), ('that',), ('that', 'part'), ('part',), ('part', 'of'), ('of',), ('of', 'heauen'), ('heauen',), ('heauen', 'where'), ('where',), ('where', 'now'), ('now',), ('now', 'it'), ('it',), ('it', 'burnes'), ('burnes',), ('burnes', ','), (',',), (',', 'marcellus'), ('marcellus',), ('marcellus', 'and'), ('and',), ('and', 'my'), ('my',), ('my', 'selfe'), ('selfe',), ('selfe', ','), (',',), (',', 'the'), ('the',), ('the', 'bell'), ('bell',), ('bell', 'then'), ('then',), ('then', 'beating'), ('beating',), ('beating', 'one'), ('one',), ('one', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'peace'), ('peace',), ('peace', ','), (',',), (',', 'breake'), ('breake',), ('breake', 'thee'), ('thee',), ('thee', 'of'), ('of',), ('of', ':'), (':',), (':', 'enter'), ('enter',), ('enter', 'the'), ('the',), ('the', 'ghost'), ('ghost',), ('ghost', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'looke'), ('looke',), ('looke', 'where'), ('where',), ('where', 'it'), ('it',), ('it', 'comes'), ('comes',), ('comes', 'againe'), ('againe',), ('againe', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barn'), ('barn',), ('barn', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'in'), ('in',), ('in', 'the'), ('the',), ('the', 'same'), ('same',), ('same', 'figure'), ('figure',), ('figure', ','), (',',), (',', 'like'), ('like',), ('like', 'the'), ('the',), ('the', 'king'), ('king',), ('king', 'that'), ('that',), ('that', "'"), ("'",), ("'", 's'), ('s',), ('s', 'dead'), ('dead',), ('dead', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'thou'), ('thou',), ('thou', 'art'), ('art',), ('art', 'a'), ('a',), ('a', 'scholler'), ('scholler',), ('scholler', ';'), (';',), (';', 'speake'), ('speake',), ('speake', 'to'), ('to',), ('to', 'it'), ('it',), ('it', 'horatio'), ('horatio',), ('horatio', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barn'), ('barn',), ('barn', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'lookes'), ('lookes',), ('lookes', 'it'), ('it',), ('it', 'not'), ('not',), ('not', 'like'), ('like',), ('like', 'the'), ('the',), ('the', 'king'), ('king',), ('king', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'marke'), ('marke',), ('marke', 'it'), ('it',), ('it', 'horatio'), ('horatio',), ('horatio', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hora'), ('hora',), ('hora', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'most'), ('most',), ('most', 'like'), ('like',), ('like', ':'), (':',), (':', 'it'), ('it',), ('it', 'harrowes'), ('harrowes',), ('harrowes', 'me'), ('me',), ('me', 'with'), ('with',), ('with', 'fear'), ('fear',), ('fear', '&'), ('&',), ('&', 'wonder'), ('wonder',), ('wonder', 'barn'), ('barn',), ('barn', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'it'), ('it',), ('it', 'would'), ('would',), ('would', 'be'), ('be',), ('be', 'spoke'), ('spoke',), ('spoke', 'too'), ('too',), ('too', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'question'), ('question',), ('question', 'it'), ('it',), ('it', 'horatio'), ('horatio',), ('horatio', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'what'), ('what',), ('what', 'art'), ('art',), ('art', 'thou'), ('thou',), ('thou', 'that'), ('that',), ('that', 'vsurp'), ('vsurp',), ('vsurp', "'"), ("'",), ("'", 'st'), ('st',), ('st', 'this'), ('this',), ('this', 'time'), ('time',), ('time', 'of'), ('of',), ('of', 'night'), ('night',), ('night', ','), (',',), (',', 'together'), ('together',), ('together', 'with'), ('with',), ('with', 'that'), ('that',), ('that', 'faire'), ('faire',), ('faire', 'and'), ('and',), ('and', 'warlike'), ('warlike',), ('warlike', 'forme'), ('forme',), ('forme', 'in'), ('in',), ('in', 'which'), ('which',), ('which', 'the'), ('the',), ('the', 'maiesty'), ('maiesty',), ('maiesty', 'of'), ('of',), ('of', 'buried'), ('buried',), ('buried', 'denmarke'), ('denmarke',), ('denmarke', 'did'), ('did',), ('did', 'sometimes'), ('sometimes',), ('sometimes', 'march'), ('march',), ('march', ':'), (':',), (':', 'by'), ('by',), ('by', 'heauen'), ('heauen',), ('heauen', 'i'), ('i',), ('i', 'charge'), ('charge',), ('charge', 'thee'), ('thee',), ('thee', 'speake'), ('speake',), ('speake', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'it'), ('it',), ('it', 'is'), ('is',), ('is', 'offended'), ('offended',), ('offended', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barn'), ('barn',), ('barn', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'see'), ('see',), ('see', ','), (',',), (',', 'it'), ('it',), ('it', 'stalkes'), ('stalkes',), ('stalkes', 'away'), ('away',), ('away', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'stay'), ('stay',), ('stay', ':'), (':',), (':', 'speake'), ('speake',), ('speake', ';'), (';',), (';', 'speake'), ('speake',), ('speake', ':'), (':',), (':', 'i'), ('i',), ('i', 'charge'), ('charge',), ('charge', 'thee'), ('thee',), ('thee', ','), (',',), (',', 'speake'), ('speake',), ('speake', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'exit'), ('exit',), ('exit', 'the'), ('the',), ('the', 'ghost'), ('ghost',), ('ghost', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', "'"), ("'",), ("'", 'tis'), ('tis',), ('tis', 'gone'), ('gone',), ('gone', ','), (',',), (',', 'and'), ('and',), ('and', 'will'), ('will',), ('will', 'not'), ('not',), ('not', 'answer'), ('answer',), ('answer', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barn'), ('barn',), ('barn', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'how'), ('how',), ('how', 'now'), ('now',), ('now', 'horatio'), ('horatio',), ('horatio', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'you'), ('you',), ('you', 'tremble'), ('tremble',), ('tremble', '&'), ('&',), ('&', 'look'), ('look',), ('look', 'pale'), ('pale',), ('pale', ':'), (':',), (':', 'is'), ('is',), ('is', 'not'), ('not',), ('not', 'this'), ('this',), ('this', 'something'), ('something',), ('something', 'more'), ('more',), ('more', 'then'), ('then',), ('then', 'fantasie'), ('fantasie',), ('fantasie', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'what'), ('what',), ('what', 'thinke'), ('thinke',), ('thinke', 'you'), ('you',), ('you', 'on'), ('on',), ('on', "'"), ("'",), ("'", 't'), ('t',), ('t', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'before'), ('before',), ('before', 'my'), ('my',), ('my', 'god'), ('god',), ('god', ','), (',',), (',', 'i'), ('i',), ('i', 'might'), ('might',), ('might', 'not'), ('not',), ('not', 'this'), ('this',), ('this', 'beleeue'), ('beleeue',), ('beleeue', 'without'), ('without',), ('without', 'the'), ('the',), ('the', 'sensible'), ('sensible',), ('sensible', 'and'), ('and',), ('and', 'true'), ('true',), ('true', 'auouch'), ('auouch',), ('auouch', 'of'), ('of',), ('of', 'mine'), ('mine',), ('mine', 'owne'), ('owne',), ('owne', 'eyes'), ('eyes',), ('eyes', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'is'), ('is',), ('is', 'it'), ('it',), ('it', 'not'), ('not',), ('not', 'like'), ('like',), ('like', 'the'), ('the',), ('the', 'king'), ('king',), ('king', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'as'), ('as',), ('as', 'thou'), ('thou',), ('thou', 'art'), ('art',), ('art', 'to'), ('to',), ('to', 'thy'), ('thy',), ('thy', 'selfe'), ('selfe',), ('selfe', ','), (',',), (',', 'such'), ('such',), ('such', 'was'), ('was',), ('was', 'the'), ('the',), ('the', 'very'), ('very',), ('very', 'armour'), ('armour',), ('armour', 'he'), ('he',), ('he', 'had'), ('had',), ('had', 'on'), ('on',), ('on', ','), (',',), (',', 'when'), ('when',), ('when', 'th'), ('th',), ('th', "'"), ("'",), ("'", 'ambitious'), ('ambitious',), ('ambitious', 'norwey'), ('norwey',), ('norwey', 'combatted'), ('combatted',), ('combatted', ':'), (':',), (':', 'so'), ('so',), ('so', 'frown'), ('frown',), ('frown', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'he'), ('he',), ('he', 'once'), ('once',), ('once', ','), (',',), (',', 'when'), ('when',), ('when', 'in'), ('in',), ('in', 'an'), ('an',), ('an', 'angry'), ('angry',), ('angry', 'parle'), ('parle',), ('parle', 'he'), ('he',), ('he', 'smot'), ('smot',), ('smot', 'the'), ('the',), ('the', 'sledded'), ('sledded',), ('sledded', 'pollax'), ('pollax',), ('pollax', 'on'), ('on',), ('on', 'the'), ('the',), ('the', 'ice'), ('ice',), ('ice', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', "'"), ("'",), ("'", 'tis'), ('tis',), ('tis', 'strange'), ('strange',), ('strange', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'thus'), ('thus',), ('thus', 'twice'), ('twice',), ('twice', 'before'), ('before',), ('before', ','), (',',), (',', 'and'), ('and',), ('and', 'iust'), ('iust',), ('iust', 'at'), ('at',), ('at', 'this'), ('this',), ('this', 'dead'), ('dead',), ('dead', 'houre'), ('houre',), ('houre', ','), (',',), (',', 'with'), ('with',), ('with', 'martiall'), ('martiall',), ('martiall', 'stalke'), ('stalke',), ('stalke', ','), (',',), (',', 'hath'), ('hath',), ('hath', 'he'), ('he',), ('he', 'gone'), ('gone',), ('gone', 'by'), ('by',), ('by', 'our'), ('our',), ('our', 'watch'), ('watch',), ('watch', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'in'), ('in',), ('in', 'what'), ('what',), ('what', 'particular'), ('particular',), ('particular', 'thought'), ('thought',), ('thought', 'to'), ('to',), ('to', 'work'), ('work',), ('work', ','), (',',), (',', 'i'), ('i',), ('i', 'know'), ('know',), ('know', 'not'), ('not',), ('not', ':'), (':',), (':', 'but'), ('but',), ('but', 'in'), ('in',), ('in', 'the'), ('the',), ('the', 'grosse'), ('grosse',), ('grosse', 'and'), ('and',), ('and', 'scope'), ('scope',), ('scope', 'of'), ('of',), ('of', 'my'), ('my',), ('my', 'opinion'), ('opinion',), ('opinion', ','), (',',), (',', 'this'), ('this',), ('this', 'boades'), ('boades',), ('boades', 'some'), ('some',), ('some', 'strange'), ('strange',), ('strange', 'erruption'), ('erruption',), ('erruption', 'to'), ('to',), ('to', 'our'), ('our',), ('our', 'state'), ('state',), ('state', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'good'), ('good',), ('good', 'now'), ('now',), ('now', 'sit'), ('sit',), ('sit', 'downe'), ('downe',), ('downe', ','), (',',), (',', '&'), ('&',), ('&', 'tell'), ('tell',), ('tell', 'me'), ('me',), ('me', 'he'), ('he',), ('he', 'that'), ('that',), ('that', 'knowes'), ('knowes',), ('knowes', 'why'), ('why',), ('why', 'this'), ('this',), ('this', 'same'), ('same',), ('same', 'strict'), ('strict',), ('strict', 'and'), ('and',), ('and', 'most'), ('most',), ('most', 'obseruant'), ('obseruant',), ('obseruant', 'watch'), ('watch',), ('watch', ','), (',',), (',', 'so'), ('so',), ('so', 'nightly'), ('nightly',), ('nightly', 'toyles'), ('toyles',), ('toyles', 'the'), ('the',), ('the', 'subiect'), ('subiect',), ('subiect', 'of'), ('of',), ('of', 'the'), ('the',), ('the', 'land'), ('land',), ('land', ','), (',',), (',', 'and'), ('and',), ('and', 'why'), ('why',), ('why', 'such'), ('such',), ('such', 'dayly'), ('dayly',), ('dayly', 'cast'), ('cast',), ('cast', 'of'), ('of',), ('of', 'brazon'), ('brazon',), ('brazon', 'cannon'), ('cannon',), ('cannon', 'and'), ('and',), ('and', 'forraigne'), ('forraigne',), ('forraigne', 'mart'), ('mart',), ('mart', 'for'), ('for',), ('for', 'implements'), ('implements',), ('implements', 'of'), ('of',), ('of', 'warre'), ('warre',), ('warre', ':'), (':',), (':', 'why'), ('why',), ('why', 'such'), ('such',), ('such', 'impresse'), ('impresse',), ('impresse', 'of'), ('of',), ('of', 'ship'), ('ship',), ('ship', '-'), ('-',), ('-', 'wrights'), ('wrights',), ('wrights', ','), (',',), (',', 'whose'), ('whose',), ('whose', 'sore'), ('sore',), ('sore', 'taske'), ('taske',), ('taske', 'do'), ('do',), ('do', "'"), ("'",), ("'", 's'), ('s',), ('s', 'not'), ('not',), ('not', 'diuide'), ('diuide',), ('diuide', 'the'), ('the',), ('the', 'sunday'), ('sunday',), ('sunday', 'from'), ('from',), ('from', 'the'), ('the',), ('the', 'weeke'), ('weeke',), ('weeke', ','), (',',), (',', 'what'), ('what',), ('what', 'might'), ('might',), ('might', 'be'), ('be',), ('be', 'toward'), ('toward',), ('toward', ','), (',',), (',', 'that'), ('that',), ('that', 'this'), ('this',), ('this', 'sweaty'), ('sweaty',), ('sweaty', 'hast'), ('hast',), ('hast', 'doth'), ('doth',), ('doth', 'make'), ('make',), ('make', 'the'), ('the',), ('the', 'night'), ('night',), ('night', 'ioynt'), ('ioynt',), ('ioynt', '-'), ('-',), ('-', 'labourer'), ('labourer',), ('labourer', 'with'), ('with',), ('with', 'the'), ('the',), ('the', 'day'), ('day',), ('day', ':'), (':',), (':', 'who'), ('who',), ('who', 'is'), ('is',), ('is', "'"), ("'",), ("'", 't'), ('t',), ('t', 'that'), ('that',), ('that', 'can'), ('can',), ('can', 'informe'), ('informe',), ('informe', 'me'), ('me',), ('me', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'that'), ('that',), ('that', 'can'), ('can',), ('can', 'i'), ('i',), ('i', ','), (',',), (',', 'at'), ('at',), ('at', 'least'), ('least',), ('least', 'the'), ('the',), ('the', 'whisper'), ('whisper',), ('whisper', 'goes'), ('goes',), ('goes', 'so'), ('so',), ('so', ':'), (':',), (':', 'our'), ('our',), ('our', 'last'), ('last',), ('last', 'king'), ('king',), ('king', ','), (',',), (',', 'whose'), ('whose',), ('whose', 'image'), ('image',), ('image', 'euen'), ('euen',), ('euen', 'but'), ('but',), ('but', 'now'), ('now',), ('now', 'appear'), ('appear',), ('appear', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'to'), ('to',), ('to', 'vs'), ('vs',), ('vs', ','), (',',), (',', 'was'), ('was',), ('was', '('), ('(',), ('(', 'as'), ('as',), ('as', 'you'), ('you',), ('you', 'know'), ('know',), ('know', ')'), (')',), (')', 'by'), ('by',), ('by', 'fortinbras'), ('fortinbras',), ('fortinbras', 'of'), ('of',), ('of', 'norway'), ('norway',), ('norway', ','), (',',), (',', '('), ('(',), ('(', 'thereto'), ('thereto',), ('thereto', 'prick'), ('prick',), ('prick', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'on'), ('on',), ('on', 'by'), ('by',), ('by', 'a'), ('a',), ('a', 'most'), ('most',), ('most', 'emulate'), ('emulate',), ('emulate', 'pride'), ('pride',), ('pride', ')'), (')',), (')', 'dar'), ('dar',), ('dar', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'to'), ('to',), ('to', 'the'), ('the',), ('the', 'combate'), ('combate',), ('combate', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'in'), ('in',), ('in', 'which'), ('which',), ('which', ','), (',',), (',', 'our'), ('our',), ('our', 'valiant'), ('valiant',), ('valiant', 'hamlet'), ('hamlet',), ('hamlet', ','), (',',), (',', '('), ('(',), ('(', 'for'), ('for',), ('for', 'so'), ('so',), ('so', 'this'), ('this',), ('this', 'side'), ('side',), ('side', 'of'), ('of',), ('of', 'our'), ('our',), ('our', 'knowne'), ('knowne',), ('knowne', 'world'), ('world',), ('world', 'esteem'), ('esteem',), ('esteem', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'him'), ('him',), ('him', ')'), (')',), (')', 'did'), ('did',), ('did', 'slay'), ('slay',), ('slay', 'this'), ('this',), ('this', 'fortinbras'), ('fortinbras',), ('fortinbras', ':'), (':',), (':', 'who'), ('who',), ('who', 'by'), ('by',), ('by', 'a'), ('a',), ('a', 'seal'), ('seal',), ('seal', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'compact'), ('compact',), ('compact', ','), (',',), (',', 'well'), ('well',), ('well', 'ratified'), ('ratified',), ('ratified', 'by'), ('by',), ('by', 'law'), ('law',), ('law', ','), (',',), (',', 'and'), ('and',), ('and', 'heraldrie'), ('heraldrie',), ('heraldrie', ','), (',',), (',', 'did'), ('did',), ('did', 'forfeite'), ('forfeite',), ('forfeite', '('), ('(',), ('(', 'with'), ('with',), ('with', 'his'), ('his',), ('his', 'life'), ('life',), ('life', ')'), (')',), (')', 'all'), ('all',), ('all', 'those'), ('those',), ('those', 'his'), ('his',), ('his', 'lands'), ('lands',), ('lands', 'which'), ('which',), ('which', 'he'), ('he',), ('he', 'stood'), ('stood',), ('stood', 'seiz'), ('seiz',), ('seiz', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'on'), ('on',), ('on', ','), (',',), (',', 'to'), ('to',), ('to', 'the'), ('the',), ('the', 'conqueror'), ('conqueror',), ('conqueror', ':'), (':',), (':', 'against'), ('against',), ('against', 'the'), ('the',), ('the', 'which'), ('which',), ('which', ','), (',',), (',', 'a'), ('a',), ('a', 'moity'), ('moity',), ('moity', 'competent'), ('competent',), ('competent', 'was'), ('was',), ('was', 'gaged'), ('gaged',), ('gaged', 'by'), ('by',), ('by', 'our'), ('our',), ('our', 'king'), ('king',), ('king', ':'), (':',), (':', 'which'), ('which',), ('which', 'had'), ('had',), ('had', 'return'), ('return',), ('return', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'to'), ('to',), ('to', 'the'), ('the',), ('the', 'inheritance'), ('inheritance',), ('inheritance', 'of'), ('of',), ('of', 'fortinbras'), ('fortinbras',), ('fortinbras', ','), (',',), (',', 'had'), ('had',), ('had', 'he'), ('he',), ('he', 'bin'), ('bin',), ('bin', 'vanquisher'), ('vanquisher',), ('vanquisher', ','), (',',), (',', 'as'), ('as',), ('as', 'by'), ('by',), ('by', 'the'), ('the',), ('the', 'same'), ('same',), ('same', 'cou'), ('cou',), ('cou', "'"), ("'",), ("'", 'nant'), ('nant',), ('nant', 'and'), ('and',), ('and', 'carriage'), ('carriage',), ('carriage', 'of'), ('of',), ('of', 'the'), ('the',), ('the', 'article'), ('article',), ('article', 'designe'), ('designe',), ('designe', ','), (',',), (',', 'his'), ('his',), ('his', 'fell'), ('fell',), ('fell', 'to'), ('to',), ('to', 'hamlet'), ('hamlet',), ('hamlet', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'now'), ('now',), ('now', 'sir'), ('sir',), ('sir', ','), (',',), (',', 'young'), ('young',), ('young', 'fortinbras'), ('fortinbras',), ('fortinbras', ','), (',',), (',', 'of'), ('of',), ('of', 'vnimproued'), ('vnimproued',), ('vnimproued', 'mettle'), ('mettle',), ('mettle', ','), (',',), (',', 'hot'), ('hot',), ('hot', 'and'), ('and',), ('and', 'full'), ('full',), ('full', ','), (',',), (',', 'hath'), ('hath',), ('hath', 'in'), ('in',), ('in', 'the'), ('the',), ('the', 'skirts'), ('skirts',), ('skirts', 'of'), ('of',), ('of', 'norway'), ('norway',), ('norway', ','), (',',), (',', 'heere'), ('heere',), ('heere', 'and'), ('and',), ('and', 'there'), ('there',), ('there', ','), (',',), (',', 'shark'), ('shark',), ('shark', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'vp'), ('vp',), ('vp', 'a'), ('a',), ('a', 'list'), ('list',), ('list', 'of'), ('of',), ('of', 'landlesse'), ('landlesse',), ('landlesse', 'resolutes'), ('resolutes',), ('resolutes', ','), (',',), (',', 'for'), ('for',), ('for', 'foode'), ('foode',), ('foode', 'and'), ('and',), ('and', 'diet'), ('diet',), ('diet', ','), (',',), (',', 'to'), ('to',), ('to', 'some'), ('some',), ('some', 'enterprize'), ('enterprize',), ('enterprize', 'that'), ('that',), ('that', 'hath'), ('hath',), ('hath', 'a'), ('a',), ('a', 'stomacke'), ('stomacke',), ('stomacke', 'in'), ('in',), ('in', "'"), ("'",), ("'", 't'), ('t',), ('t', ':'), (':',), (':', 'which'), ('which',), ('which', 'is'), ('is',), ('is', 'no'), ('no',), ('no', 'other'), ('other',), ('other', '('), ('(',), ('(', 'and'), ('and',), ('and', 'it'), ('it',), ('it', 'doth'), ('doth',), ('doth', 'well'), ('well',), ('well', 'appeare'), ('appeare',), ('appeare', 'vnto'), ('vnto',), ('vnto', 'our'), ('our',), ('our', 'state'), ('state',), ('state', ')'), (')',), (')', 'but'), ('but',), ('but', 'to'), ('to',), ('to', 'recouer'), ('recouer',), ('recouer', 'of'), ('of',), ('of', 'vs'), ('vs',), ('vs', 'by'), ('by',), ('by', 'strong'), ('strong',), ('strong', 'hand'), ('hand',), ('hand', 'and'), ('and',), ('and', 'termes'), ('termes',), ('termes', 'compulsatiue'), ('compulsatiue',), ('compulsatiue', ','), (',',), (',', 'those'), ('those',), ('those', 'foresaid'), ('foresaid',), ('foresaid', 'lands'), ('lands',), ('lands', 'so'), ('so',), ('so', 'by'), ('by',), ('by', 'his'), ('his',), ('his', 'father'), ('father',), ('father', 'lost'), ('lost',), ('lost', ':'), (':',), (':', 'and'), ('and',), ('and', 'this'), ('this',), ('this', '('), ('(',), ('(', 'i'), ('i',), ('i', 'take'), ('take',), ('take', 'it'), ('it',), ('it', ')'), (')',), (')', 'is'), ('is',), ('is', 'the'), ('the',), ('the', 'maine'), ('maine',), ('maine', 'motiue'), ('motiue',), ('motiue', 'of'), ('of',), ('of', 'our'), ('our',), ('our', 'preparations'), ('preparations',), ('preparations', ','), (',',), (',', 'the'), ('the',), ('the', 'sourse'), ('sourse',), ('sourse', 'of'), ('of',), ('of', 'this'), ('this',), ('this', 'our'), ('our',), ('our', 'watch'), ('watch',), ('watch', ','), (',',), (',', 'and'), ('and',), ('and', 'the'), ('the',), ('the', 'cheefe'), ('cheefe',), ('cheefe', 'head'), ('head',), ('head', 'of'), ('of',), ('of', 'this'), ('this',), ('this', 'post'), ('post',), ('post', '-'), ('-',), ('-', 'hast'), ('hast',), ('hast', ','), (',',), (',', 'and'), ('and',), ('and', 'romage'), ('romage',), ('romage', 'in'), ('in',), ('in', 'the'), ('the',), ('the', 'land'), ('land',), ('land', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'enter'), ('enter',), ('enter', 'ghost'), ('ghost',), ('ghost', 'againe'), ('againe',), ('againe', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'but'), ('but',), ('but', 'soft'), ('soft',), ('soft', ','), (',',), (',', 'behold'), ('behold',), ('behold', ':'), (':',), (':', 'loe'), ('loe',), ('loe', ','), (',',), (',', 'where'), ('where',), ('where', 'it'), ('it',), ('it', 'comes'), ('comes',), ('comes', 'againe'), ('againe',), ('againe', ':'), (':',), (':', 'ile'), ('ile',), ('ile', 'crosse'), ('crosse',), ('crosse', 'it'), ('it',), ('it', ','), (',',), (',', 'though'), ('though',), ('though', 'it'), ('it',), ('it', 'blast'), ('blast',), ('blast', 'me'), ('me',), ('me', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'stay'), ('stay',), ('stay', 'illusion'), ('illusion',), ('illusion', ':'), (':',), (':', 'if'), ('if',), ('if', 'thou'), ('thou',), ('thou', 'hast'), ('hast',), ('hast', 'any'), ('any',), ('any', 'sound'), ('sound',), ('sound', ','), (',',), (',', 'or'), ('or',), ('or', 'vse'), ('vse',), ('vse', 'of'), ('of',), ('of', 'voyce'), ('voyce',), ('voyce', ','), (',',), (',', 'speake'), ('speake',), ('speake', 'to'), ('to',), ('to', 'me'), ('me',), ('me', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'if'), ('if',), ('if', 'there'), ('there',), ('there', 'be'), ('be',), ('be', 'any'), ('any',), ('any', 'good'), ('good',), ('good', 'thing'), ('thing',), ('thing', 'to'), ('to',), ('to', 'be'), ('be',), ('be', 'done'), ('done',), ('done', ','), (',',), (',', 'that'), ('that',), ('that', 'may'), ('may',), ('may', 'to'), ('to',), ('to', 'thee'), ('thee',), ('thee', 'do'), ('do',), ('do', 'ease'), ('ease',), ('ease', ','), (',',), (',', 'and'), ('and',), ('and', 'grace'), ('grace',), ('grace', 'to'), ('to',), ('to', 'me'), ('me',), ('me', ';'), (';',), (';', 'speak'), ('speak',), ('speak', 'to'), ('to',), ('to', 'me'), ('me',), ('me', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'if'), ('if',), ('if', 'thou'), ('thou',), ('thou', 'art'), ('art',), ('art', 'priuy'), ('priuy',), ('priuy', 'to'), ('to',), ('to', 'thy'), ('thy',), ('thy', 'countries'), ('countries',), ('countries', 'fate'), ('fate',), ('fate', '('), ('(',), ('(', 'which'), ('which',), ('which', 'happily'), ('happily',), ('happily', 'foreknowing'), ('foreknowing',), ('foreknowing', 'may'), ('may',), ('may', 'auoyd'), ('auoyd',), ('auoyd', ')'), (')',), (')', 'oh'), ('oh',), ('oh', 'speake'), ('speake',), ('speake', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'or'), ('or',), ('or', ','), (',',), (',', 'if'), ('if',), ('if', 'thou'), ('thou',), ('thou', 'hast'), ('hast',), ('hast', 'vp'), ('vp',), ('vp', '-'), ('-',), ('-', 'hoorded'), ('hoorded',), ('hoorded', 'in'), ('in',), ('in', 'thy'), ('thy',), ('thy', 'life'), ('life',), ('life', 'extorted'), ('extorted',), ('extorted', 'treasure'), ('treasure',), ('treasure', 'in'), ('in',), ('in', 'the'), ('the',), ('the', 'wombe'), ('wombe',), ('wombe', 'of'), ('of',), ('of', 'earth'), ('earth',), ('earth', ','), (',',), (',', '('), ('(',), ('(', 'for'), ('for',), ('for', 'which'), ('which',), ('which', ','), (',',), (',', 'they'), ('they',), ('they', 'say'), ('say',), ('say', ','), (',',), (',', 'you'), ('you',), ('you', 'spirits'), ('spirits',), ('spirits', 'oft'), ('oft',), ('oft', 'walke'), ('walke',), ('walke', 'in'), ('in',), ('in', 'death'), ('death',), ('death', ')'), (')',), (')', 'speake'), ('speake',), ('speake', 'of'), ('of',), ('of', 'it'), ('it',), ('it', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'stay'), ('stay',), ('stay', ','), (',',), (',', 'and'), ('and',), ('and', 'speake'), ('speake',), ('speake', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'stop'), ('stop',), ('stop', 'it'), ('it',), ('it', 'marcellus'), ('marcellus',), ('marcellus', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'shall'), ('shall',), ('shall', 'i'), ('i',), ('i', 'strike'), ('strike',), ('strike', 'at'), ('at',), ('at', 'it'), ('it',), ('it', 'with'), ('with',), ('with', 'my'), ('my',), ('my', 'partizan'), ('partizan',), ('partizan', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'do'), ('do',), ('do', ','), (',',), (',', 'if'), ('if',), ('if', 'it'), ('it',), ('it', 'will'), ('will',), ('will', 'not'), ('not',), ('not', 'stand'), ('stand',), ('stand', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barn'), ('barn',), ('barn', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', "'"), ("'",), ("'", 'tis'), ('tis',), ('tis', 'heere'), ('heere',), ('heere', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', "'"), ("'",), ("'", 'tis'), ('tis',), ('tis', 'heere'), ('heere',), ('heere', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', "'"), ("'",), ("'", 'tis'), ('tis',), ('tis', 'gone'), ('gone',), ('gone', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'exit'), ('exit',), ('exit', 'ghost'), ('ghost',), ('ghost', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'we'), ('we',), ('we', 'do'), ('do',), ('do', 'it'), ('it',), ('it', 'wrong'), ('wrong',), ('wrong', ','), (',',), (',', 'being'), ('being',), ('being', 'so'), ('so',), ('so', 'maiesticall'), ('maiesticall',), ('maiesticall', 'to'), ('to',), ('to', 'offer'), ('offer',), ('offer', 'it'), ('it',), ('it', 'the'), ('the',), ('the', 'shew'), ('shew',), ('shew', 'of'), ('of',), ('of', 'violence'), ('violence',), ('violence', ','), (',',), (',', 'for'), ('for',), ('for', 'it'), ('it',), ('it', 'is'), ('is',), ('is', 'as'), ('as',), ('as', 'the'), ('the',), ('the', 'ayre'), ('ayre',), ('ayre', ','), (',',), (',', 'invulnerable'), ('invulnerable',), ('invulnerable', ','), (',',), (',', 'and'), ('and',), ('and', 'our'), ('our',), ('our', 'vaine'), ('vaine',), ('vaine', 'blowes'), ('blowes',), ('blowes', ','), (',',), (',', 'malicious'), ('malicious',), ('malicious', 'mockery'), ('mockery',), ('mockery', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'barn'), ('barn',), ('barn', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'it'), ('it',), ('it', 'was'), ('was',), ('was', 'about'), ('about',), ('about', 'to'), ('to',), ('to', 'speake'), ('speake',), ('speake', ','), (',',), (',', 'when'), ('when',), ('when', 'the'), ('the',), ('the', 'cocke'), ('cocke',), ('cocke', 'crew'), ('crew',), ('crew', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'and'), ('and',), ('and', 'then'), ('then',), ('then', 'it'), ('it',), ('it', 'started'), ('started',), ('started', ','), (',',), (',', 'like'), ('like',), ('like', 'a'), ('a',), ('a', 'guilty'), ('guilty',), ('guilty', 'thing'), ('thing',), ('thing', 'vpon'), ('vpon',), ('vpon', 'a'), ('a',), ('a', 'fearfull'), ('fearfull',), ('fearfull', 'summons'), ('summons',), ('summons', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'i'), ('i',), ('i', 'haue'), ('haue',), ('haue', 'heard'), ('heard',), ('heard', ','), (',',), (',', 'the'), ('the',), ('the', 'cocke'), ('cocke',), ('cocke', 'that'), ('that',), ('that', 'is'), ('is',), ('is', 'the'), ('the',), ('the', 'trumpet'), ('trumpet',), ('trumpet', 'to'), ('to',), ('to', 'the'), ('the',), ('the', 'day'), ('day',), ('day', ','), (',',), (',', 'doth'), ('doth',), ('doth', 'with'), ('with',), ('with', 'his'), ('his',), ('his', 'lofty'), ('lofty',), ('lofty', 'and'), ('and',), ('and', 'shrill'), ('shrill',), ('shrill', '-'), ('-',), ('-', 'sounding'), ('sounding',), ('sounding', 'throate'), ('throate',), ('throate', 'awake'), ('awake',), ('awake', 'the'), ('the',), ('the', 'god'), ('god',), ('god', 'of'), ('of',), ('of', 'day'), ('day',), ('day', ':'), (':',), (':', 'and'), ('and',), ('and', 'at'), ('at',), ('at', 'his'), ('his',), ('his', 'warning'), ('warning',), ('warning', ','), (',',), (',', 'whether'), ('whether',), ('whether', 'in'), ('in',), ('in', 'sea'), ('sea',), ('sea', ','), (',',), (',', 'or'), ('or',), ('or', 'fire'), ('fire',), ('fire', ','), (',',), (',', 'in'), ('in',), ('in', 'earth'), ('earth',), ('earth', ','), (',',), (',', 'or'), ('or',), ('or', 'ayre'), ('ayre',), ('ayre', ','), (',',), (',', 'th'), ('th',), ('th', "'"), ("'",), ("'", 'extrauagant'), ('extrauagant',), ('extrauagant', ','), (',',), (',', 'and'), ('and',), ('and', 'erring'), ('erring',), ('erring', 'spirit'), ('spirit',), ('spirit', ','), (',',), (',', 'hyes'), ('hyes',), ('hyes', 'to'), ('to',), ('to', 'his'), ('his',), ('his', 'confine'), ('confine',), ('confine', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'and'), ('and',), ('and', 'of'), ('of',), ('of', 'the'), ('the',), ('the', 'truth'), ('truth',), ('truth', 'heerein'), ('heerein',), ('heerein', ','), (',',), (',', 'this'), ('this',), ('this', 'present'), ('present',), ('present', 'obiect'), ('obiect',), ('obiect', 'made'), ('made',), ('made', 'probation'), ('probation',), ('probation', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'mar'), ('mar',), ('mar', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'it'), ('it',), ('it', 'faded'), ('faded',), ('faded', 'on'), ('on',), ('on', 'the'), ('the',), ('the', 'crowing'), ('crowing',), ('crowing', 'of'), ('of',), ('of', 'the'), ('the',), ('the', 'cocke'), ('cocke',), ('cocke', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'some'), ('some',), ('some', 'sayes'), ('sayes',), ('sayes', ','), (',',), (',', 'that'), ('that',), ('that', 'euer'), ('euer',), ('euer', "'"), ("'",), ("'", 'gainst'), ('gainst',), ('gainst', 'that'), ('that',), ('that', 'season'), ('season',), ('season', 'comes'), ('comes',), ('comes', 'wherein'), ('wherein',), ('wherein', 'our'), ('our',), ('our', 'sauiours'), ('sauiours',), ('sauiours', 'birch'), ('birch',), ('birch', 'is'), ('is',), ('is', 'celebrated'), ('celebrated',), ('celebrated', ','), (',',), (',', 'the'), ('the',), ('the', 'bird'), ('bird',), ('bird', 'of'), ('of',), ('of', 'dawning'), ('dawning',), ('dawning', 'singeth'), ('singeth',), ('singeth', 'all'), ('all',), ('all', 'night'), ('night',), ('night', 'long'), ('long',), ('long', ':'), (':',), (':', 'and'), ('and',), ('and', 'then'), ('then',), ('then', '('), ('(',), ('(', 'they'), ('they',), ('they', 'say'), ('say',), ('say', ')'), (')',), (')', 'no'), ('no',), ('no', 'spirit'), ('spirit',), ('spirit', 'can'), ('can',), ('can', 'walke'), ('walke',), ('walke', 'abroad'), ('abroad',), ('abroad', ','), (',',), (',', 'the'), ('the',), ('the', 'nights'), ('nights',), ('nights', 'are'), ('are',), ('are', 'wholsome'), ('wholsome',), ('wholsome', ','), (',',), (',', 'then'), ('then',), ('then', 'no'), ('no',), ('no', 'planets'), ('planets',), ('planets', 'strike'), ('strike',), ('strike', ','), (',',), (',', 'no'), ('no',), ('no', 'faiery'), ('faiery',), ('faiery', 'talkes'), ('talkes',), ('talkes', ','), (',',), (',', 'nor'), ('nor',), ('nor', 'witch'), ('witch',), ('witch', 'hath'), ('hath',), ('hath', 'power'), ('power',), ('power', 'to'), ('to',), ('to', 'charme'), ('charme',), ('charme', ':'), (':',), (':', 'so'), ('so',), ('so', 'hallow'), ('hallow',), ('hallow', "'"), ("'",), ("'", 'd'), ('d',), ('d', ','), (',',), (',', 'and'), ('and',), ('and', 'so'), ('so',), ('so', 'gracious'), ('gracious',), ('gracious', 'is'), ('is',), ('is', 'the'), ('the',), ('the', 'time'), ('time',), ('time', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'so'), ('so',), ('so', 'haue'), ('haue',), ('haue', 'i'), ('i',), ('i', 'heard'), ('heard',), ('heard', ','), (',',), (',', 'and'), ('and',), ('and', 'do'), ('do',), ('do', 'in'), ('in',), ('in', 'part'), ('part',), ('part', 'beleeue'), ('beleeue',), ('beleeue', 'it'), ('it',), ('it', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# ...
# [('<s>',), ('<s>', 'the'), ('the',), ('the', 'rest'), ('rest',), ('rest', 'is'), ('is',), ('is', 'silence'), ('silence',), ('silence', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'o'), ('o',), ('o', ','), (',',), (',', 'o'), ('o',), ('o', ','), (',',), (',', 'o'), ('o',), ('o', ','), (',',), (',', 'o'), ('o',), ('o', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'dyes'), ('dyes',), ('dyes', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hora'), ('hora',), ('hora', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'now'), ('now',), ('now', 'cracke'), ('cracke',), ('cracke', 'a'), ('a',), ('a', 'noble'), ('noble',), ('noble', 'heart'), ('heart',), ('heart', ':'), (':',), (':', 'goodnight'), ('goodnight',), ('goodnight', 'sweet'), ('sweet',), ('sweet', 'prince'), ('prince',), ('prince', ','), (',',), (',', 'and'), ('and',), ('and', 'flights'), ('flights',), ('flights', 'of'), ('of',), ('of', 'angels'), ('angels',), ('angels', 'sing'), ('sing',), ('sing', 'thee'), ('thee',), ('thee', 'to'), ('to',), ('to', 'thy'), ('thy',), ('thy', 'rest'), ('rest',), ('rest', ','), (',',), (',', 'why'), ('why',), ('why', 'do'), ('do',), ('do', "'"), ("'",), ("'", 's'), ('s',), ('s', 'the'), ('the',), ('the', 'drumme'), ('drumme',), ('drumme', 'come'), ('come',), ('come', 'hither'), ('hither',), ('hither', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'enter'), ('enter',), ('enter', 'fortinbras'), ('fortinbras',), ('fortinbras', 'and'), ('and',), ('and', 'english'), ('english',), ('english', 'ambassador'), ('ambassador',), ('ambassador', ','), (',',), (',', 'with'), ('with',), ('with', 'drumme'), ('drumme',), ('drumme', ','), (',',), (',', 'colours'), ('colours',), ('colours', ','), (',',), (',', 'and'), ('and',), ('and', 'attendants'), ('attendants',), ('attendants', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'fortin'), ('fortin',), ('fortin', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'where'), ('where',), ('where', 'is'), ('is',), ('is', 'this'), ('this',), ('this', 'sight'), ('sight',), ('sight', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'what'), ('what',), ('what', 'is'), ('is',), ('is', 'it'), ('it',), ('it', 'ye'), ('ye',), ('ye', 'would'), ('would',), ('would', 'see'), ('see',), ('see', ';'), (';',), (';', 'if'), ('if',), ('if', 'ought'), ('ought',), ('ought', 'of'), ('of',), ('of', 'woe'), ('woe',), ('woe', ','), (',',), (',', 'or'), ('or',), ('or', 'wonder'), ('wonder',), ('wonder', ','), (',',), (',', 'cease'), ('cease',), ('cease', 'your'), ('your',), ('your', 'search'), ('search',), ('search', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'for'), ('for',), ('for', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'his'), ('his',), ('his', 'quarry'), ('quarry',), ('quarry', 'cries'), ('cries',), ('cries', 'on'), ('on',), ('on', 'hauocke'), ('hauocke',), ('hauocke', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'oh'), ('oh',), ('oh', 'proud'), ('proud',), ('proud', 'death'), ('death',), ('death', ','), (',',), (',', 'what'), ('what',), ('what', 'feast'), ('feast',), ('feast', 'is'), ('is',), ('is', 'toward'), ('toward',), ('toward', 'in'), ('in',), ('in', 'thine'), ('thine',), ('thine', 'eternall'), ('eternall',), ('eternall', 'cell'), ('cell',), ('cell', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'that'), ('that',), ('that', 'thou'), ('thou',), ('thou', 'so'), ('so',), ('so', 'many'), ('many',), ('many', 'princes'), ('princes',), ('princes', ','), (',',), (',', 'at'), ('at',), ('at', 'a'), ('a',), ('a', 'shoote'), ('shoote',), ('shoote', ','), (',',), (',', 'so'), ('so',), ('so', 'bloodily'), ('bloodily',), ('bloodily', 'hast'), ('hast',), ('hast', 'strooke'), ('strooke',), ('strooke', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'amb'), ('amb',), ('amb', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'the'), ('the',), ('the', 'sight'), ('sight',), ('sight', 'is'), ('is',), ('is', 'dismall'), ('dismall',), ('dismall', ','), (',',), (',', 'and'), ('and',), ('and', 'our'), ('our',), ('our', 'affaires'), ('affaires',), ('affaires', 'from'), ('from',), ('from', 'england'), ('england',), ('england', 'come'), ('come',), ('come', 'too'), ('too',), ('too', 'late'), ('late',), ('late', ','), (',',), (',', 'the'), ('the',), ('the', 'eares'), ('eares',), ('eares', 'are'), ('are',), ('are', 'senselesse'), ('senselesse',), ('senselesse', 'that'), ('that',), ('that', 'should'), ('should',), ('should', 'giue'), ('giue',), ('giue', 'vs'), ('vs',), ('vs', 'hearing'), ('hearing',), ('hearing', ','), (',',), (',', 'to'), ('to',), ('to', 'tell'), ('tell',), ('tell', 'him'), ('him',), ('him', 'his'), ('his',), ('his', 'command'), ('command',), ('command', "'"), ("'",), ("'", 'ment'), ('ment',), ('ment', 'is'), ('is',), ('is', 'fulfill'), ('fulfill',), ('fulfill', "'"), ("'",), ("'", 'd'), ('d',), ('d', ','), (',',), (',', 'that'), ('that',), ('that', 'rosincrance'), ('rosincrance',), ('rosincrance', 'and'), ('and',), ('and', 'guildensterne'), ('guildensterne',), ('guildensterne', 'are'), ('are',), ('are', 'dead'), ('dead',), ('dead', ':'), (':',), (':', 'where'), ('where',), ('where', 'should'), ('should',), ('should', 'we'), ('we',), ('we', 'haue'), ('haue',), ('haue', 'our'), ('our',), ('our', 'thankes'), ('thankes',), ('thankes', '?'), ('?',), ('?', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'not'), ('not',), ('not', 'from'), ('from',), ('from', 'his'), ('his',), ('his', 'mouth'), ('mouth',), ('mouth', ','), (',',), (',', 'had'), ('had',), ('had', 'it'), ('it',), ('it', 'th'), ('th',), ('th', "'"), ("'",), ("'", 'abilitie'), ('abilitie',), ('abilitie', 'of'), ('of',), ('of', 'life'), ('life',), ('life', 'to'), ('to',), ('to', 'thanke'), ('thanke',), ('thanke', 'you'), ('you',), ('you', ':'), (':',), (':', 'he'), ('he',), ('he', 'neuer'), ('neuer',), ('neuer', 'gaue'), ('gaue',), ('gaue', 'command'), ('command',), ('command', "'"), ("'",), ("'", 'ment'), ('ment',), ('ment', 'for'), ('for',), ('for', 'their'), ('their',), ('their', 'death'), ('death',), ('death', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'but'), ('but',), ('but', 'since'), ('since',), ('since', 'so'), ('so',), ('so', 'iumpe'), ('iumpe',), ('iumpe', 'vpon'), ('vpon',), ('vpon', 'this'), ('this',), ('this', 'bloodie'), ('bloodie',), ('bloodie', 'question'), ('question',), ('question', ','), (',',), (',', 'you'), ('you',), ('you', 'from'), ('from',), ('from', 'the'), ('the',), ('the', 'polake'), ('polake',), ('polake', 'warres'), ('warres',), ('warres', ','), (',',), (',', 'and'), ('and',), ('and', 'you'), ('you',), ('you', 'from'), ('from',), ('from', 'england'), ('england',), ('england', 'are'), ('are',), ('are', 'heere'), ('heere',), ('heere', 'arriued'), ('arriued',), ('arriued', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'giue'), ('giue',), ('giue', 'order'), ('order',), ('order', 'that'), ('that',), ('that', 'these'), ('these',), ('these', 'bodies'), ('bodies',), ('bodies', 'high'), ('high',), ('high', 'on'), ('on',), ('on', 'a'), ('a',), ('a', 'stage'), ('stage',), ('stage', 'be'), ('be',), ('be', 'placed'), ('placed',), ('placed', 'to'), ('to',), ('to', 'the'), ('the',), ('the', 'view'), ('view',), ('view', ','), (',',), (',', 'and'), ('and',), ('and', 'let'), ('let',), ('let', 'me'), ('me',), ('me', 'speake'), ('speake',), ('speake', 'to'), ('to',), ('to', 'th'), ('th',), ('th', "'"), ("'",), ("'", 'yet'), ('yet',), ('yet', 'vnknowing'), ('vnknowing',), ('vnknowing', 'world'), ('world',), ('world', ','), (',',), (',', 'how'), ('how',), ('how', 'these'), ('these',), ('these', 'things'), ('things',), ('things', 'came'), ('came',), ('came', 'about'), ('about',), ('about', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'so'), ('so',), ('so', 'shall'), ('shall',), ('shall', 'you'), ('you',), ('you', 'heare'), ('heare',), ('heare', 'of'), ('of',), ('of', 'carnall'), ('carnall',), ('carnall', ','), (',',), (',', 'bloudie'), ('bloudie',), ('bloudie', ','), (',',), (',', 'and'), ('and',), ('and', 'vnnaturall'), ('vnnaturall',), ('vnnaturall', 'acts'), ('acts',), ('acts', ','), (',',), (',', 'of'), ('of',), ('of', 'accidentall'), ('accidentall',), ('accidentall', 'iudgements'), ('iudgements',), ('iudgements', ','), (',',), (',', 'casuall'), ('casuall',), ('casuall', 'slaughters'), ('slaughters',), ('slaughters', 'of'), ('of',), ('of', 'death'), ('death',), ('death', "'"), ("'",), ("'", 's'), ('s',), ('s', 'put'), ('put',), ('put', 'on'), ('on',), ('on', 'by'), ('by',), ('by', 'cunning'), ('cunning',), ('cunning', ','), (',',), (',', 'and'), ('and',), ('and', 'forc'), ('forc',), ('forc', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'cause'), ('cause',), ('cause', ','), (',',), (',', 'and'), ('and',), ('and', 'in'), ('in',), ('in', 'this'), ('this',), ('this', 'vpshot'), ('vpshot',), ('vpshot', ','), (',',), (',', 'purposes'), ('purposes',), ('purposes', 'mistooke'), ('mistooke',), ('mistooke', ','), (',',), (',', 'falne'), ('falne',), ('falne', 'on'), ('on',), ('on', 'the'), ('the',), ('the', 'inuentors'), ('inuentors',), ('inuentors', 'head'), ('head',), ('head', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'all'), ('all',), ('all', 'this'), ('this',), ('this', 'can'), ('can',), ('can', 'i'), ('i',), ('i', 'truly'), ('truly',), ('truly', 'deliuer'), ('deliuer',), ('deliuer', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'for'), ('for',), ('for', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'let'), ('let',), ('let', 'vs'), ('vs',), ('vs', 'hast'), ('hast',), ('hast', 'to'), ('to',), ('to', 'heare'), ('heare',), ('heare', 'it'), ('it',), ('it', ','), (',',), (',', 'and'), ('and',), ('and', 'call'), ('call',), ('call', 'the'), ('the',), ('the', 'noblest'), ('noblest',), ('noblest', 'to'), ('to',), ('to', 'the'), ('the',), ('the', 'audience'), ('audience',), ('audience', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'for'), ('for',), ('for', 'me'), ('me',), ('me', ','), (',',), (',', 'with'), ('with',), ('with', 'sorrow'), ('sorrow',), ('sorrow', ','), (',',), (',', 'i'), ('i',), ('i', 'embrace'), ('embrace',), ('embrace', 'my'), ('my',), ('my', 'fortune'), ('fortune',), ('fortune', ','), (',',), (',', 'i'), ('i',), ('i', 'haue'), ('haue',), ('haue', 'some'), ('some',), ('some', 'rites'), ('rites',), ('rites', 'of'), ('of',), ('of', 'memory'), ('memory',), ('memory', 'in'), ('in',), ('in', 'this'), ('this',), ('this', 'kingdome'), ('kingdome',), ('kingdome', ','), (',',), (',', 'which'), ('which',), ('which', 'are'), ('are',), ('are', 'to'), ('to',), ('to', 'claime'), ('claime',), ('claime', ','), (',',), (',', 'my'), ('my',), ('my', 'vantage'), ('vantage',), ('vantage', 'doth'), ('doth',), ('doth', 'inuite'), ('inuite',), ('inuite', 'me'), ('me',), ('me', ','), (',',), (',', 'hor'), ('hor',), ('hor', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'of'), ('of',), ('of', 'that'), ('that',), ('that', 'i'), ('i',), ('i', 'shall'), ('shall',), ('shall', 'haue'), ('haue',), ('haue', 'alwayes'), ('alwayes',), ('alwayes', 'cause'), ('cause',), ('cause', 'to'), ('to',), ('to', 'speake'), ('speake',), ('speake', ','), (',',), (',', 'and'), ('and',), ('and', 'from'), ('from',), ('from', 'his'), ('his',), ('his', 'mouth'), ('mouth',), ('mouth', 'whose'), ('whose',), ('whose', 'voyce'), ('voyce',), ('voyce', 'will'), ('will',), ('will', 'draw'), ('draw',), ('draw', 'on'), ('on',), ('on', 'more'), ('more',), ('more', ':'), (':',), (':', 'but'), ('but',), ('but', 'let'), ('let',), ('let', 'this'), ('this',), ('this', 'same'), ('same',), ('same', 'be'), ('be',), ('be', 'presently'), ('presently',), ('presently', 'perform'), ('perform',), ('perform', "'"), ("'",), ("'", 'd'), ('d',), ('d', ','), (',',), (',', 'euen'), ('euen',), ('euen', 'whiles'), ('whiles',), ('whiles', 'mens'), ('mens',), ('mens', 'mindes'), ('mindes',), ('mindes', 'are'), ('are',), ('are', 'wilde'), ('wilde',), ('wilde', ','), (',',), (',', 'lest'), ('lest',), ('lest', 'more'), ('more',), ('more', 'mischance'), ('mischance',), ('mischance', 'on'), ('on',), ('on', 'plots'), ('plots',), ('plots', ','), (',',), (',', 'and'), ('and',), ('and', 'errors'), ('errors',), ('errors', 'happen'), ('happen',), ('happen', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'for'), ('for',), ('for', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'let'), ('let',), ('let', 'foure'), ('foure',), ('foure', 'captaines'), ('captaines',), ('captaines', 'beare'), ('beare',), ('beare', 'hamlet'), ('hamlet',), ('hamlet', 'like'), ('like',), ('like', 'a'), ('a',), ('a', 'soldier'), ('soldier',), ('soldier', 'to'), ('to',), ('to', 'the'), ('the',), ('the', 'stage'), ('stage',), ('stage', ','), (',',), (',', 'for'), ('for',), ('for', 'he'), ('he',), ('he', 'was'), ('was',), ('was', 'likely'), ('likely',), ('likely', ','), (',',), (',', 'had'), ('had',), ('had', 'he'), ('he',), ('he', 'beene'), ('beene',), ('beene', 'put'), ('put',), ('put', 'on'), ('on',), ('on', 'to'), ('to',), ('to', 'haue'), ('haue',), ('haue', 'prou'), ('prou',), ('prou', "'"), ("'",), ("'", 'd'), ('d',), ('d', 'most'), ('most',), ('most', 'royally'), ('royally',), ('royally', ':'), (':',), (':', 'and'), ('and',), ('and', 'for'), ('for',), ('for', 'his'), ('his',), ('his', 'passage'), ('passage',), ('passage', ','), (',',), (',', 'the'), ('the',), ('the', 'souldiours'), ('souldiours',), ('souldiours', 'musicke'), ('musicke',), ('musicke', ','), (',',), (',', 'and'), ('and',), ('and', 'the'), ('the',), ('the', 'rites'), ('rites',), ('rites', 'of'), ('of',), ('of', 'warre'), ('warre',), ('warre', 'speake'), ('speake',), ('speake', 'lowdly'), ('lowdly',), ('lowdly', 'for'), ('for',), ('for', 'him'), ('him',), ('him', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'take'), ('take',), ('take', 'vp'), ('vp',), ('vp', 'the'), ('the',), ('the', 'body'), ('body',), ('body', ';'), (';',), (';', 'such'), ('such',), ('such', 'a'), ('a',), ('a', 'sight'), ('sight',), ('sight', 'as'), ('as',), ('as', 'this'), ('this',), ('this', 'becomes'), ('becomes',), ('becomes', 'the'), ('the',), ('the', 'field'), ('field',), ('field', ','), (',',), (',', 'but'), ('but',), ('but', 'heere'), ('heere',), ('heere', 'shewes'), ('shewes',), ('shewes', 'much'), ('much',), ('much', 'amis'), ('amis',), ('amis', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'go'), ('go',), ('go', ','), (',',), (',', 'bid'), ('bid',), ('bid', 'the'), ('the',), ('the', 'souldiers'), ('souldiers',), ('souldiers', 'shoote'), ('shoote',), ('shoote', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'exeunt'), ('exeunt',), ('exeunt', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'marching'), ('marching',), ('marching', ':'), (':',), (':', 'after'), ('after',), ('after', 'the'), ('the',), ('the', 'which'), ('which',), ('which', ','), (',',), (',', 'a'), ('a',), ('a', 'peale'), ('peale',), ('peale', 'of'), ('of',), ('of', 'ordenance'), ('ordenance',), ('ordenance', 'are'), ('are',), ('are', 'shot'), ('shot',), ('shot', 'off'), ('off',), ('off', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'finis'), ('finis',), ('finis', '.'), ('.',), ('.', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'the'), ('the',), ('the', 'tragedie'), ('tragedie',), ('tragedie', 'of'), ('of',), ('of', 'hamlet'), ('hamlet',), ('hamlet', ','), (',',), (',', 'prince'), ('prince',), ('prince', 'of'), ('of',), ('of', 'denmarke'), ('denmarke',), ('denmarke', '.'), ('.',), ('.', '</s>'), ('</s>',)]

# %%
list(flat_text)
# Out:
# ['<s>',
#  '[',
#  'the',
#  'tragedie',
#  'of',
#  'hamlet',
#  'by',
#  'william',
#  'shakespeare',
#  '1599',
#  ']',
#  '</s>',
#  '<s>',
#  'actus',
#  'primus',
#  '.',
#  '</s>',
#  '<s>',
#  'scoena',
#  'prima',
#  '.',
#  '</s>',
#  '<s>',
#  'enter',
#  'barnardo',
#  'and',
#  'francisco',
#  'two',
#  'centinels',
#  '.',
#  '</s>',
#  '<s>',
#  'barnardo',
#  '.',
#  '</s>',
#  '<s>',
#  'who',
#  "'",
#  's',
#  'there',
#  '?',
#  '</s>',
#  '<s>',
#  'fran',
#  '.',
#  '</s>',
#  '<s>',
#  'nay',
#  'answer',
#  'me',
#  ':',
#  'stand',
#  '&',
#  'vnfold',
#  'your',
#  'selfe',
#  '</s>',
#  '<s>',
#  'bar',
#  '.',
#  '</s>',
#  '<s>',
#  'long',
#  'liue',
#  'the',
#  'king',
#  '</s>',
#  '<s>',
#  'fran',
#  '.',
#  '</s>',
#  '<s>',
#  'barnardo',
#  '?',
#  '</s>',
#  '<s>',
#  'bar',
#  '.',
#  '</s>',
#  '<s>',
#  'he',
#  '</s>',
#  '<s>',
#  'fran',
#  '.',
#  '</s>',
#  '<s>',
#  'you',
#  'come',
#  'most',
#  'carefully',
#  'vpon',
#  'your',
#  'houre',
#  '</s>',
#  '<s>',
#  'bar',
#  '.',
#  '</s>',
#  '<s>',
#  "'",
#  'tis',
#  'now',
#  'strook',
#  'twelue',
#  ',',
#  'get',
#  'thee',
#  'to',
#  'bed',
#  'francisco',
#  '</s>',
#  '<s>',
#  'fran',
#  '.',
#  '</s>',
#  '<s>',
#  'for',
#  'this',
#  'releefe',
#  'much',
#  'thankes',
#  ':',
#  "'",
#  'tis',
#  'bitter',
#  'cold',
#  ',',
#  'and',
#  'i',
#  'am',
#  'sicke',
#  'at',
#  'heart',
#  '</s>',
#  '<s>',
#  'barn',
#  '.',
#  '</s>',
#  '<s>',
#  'haue',
#  'you',
#  'had',
#  'quiet',
#  'guard',
#  '?',
#  '</s>',
#  '<s>',
#  'fran',
#  '.',
#  '</s>',
#  '<s>',
#  'not',
#  'a',
#  'mouse',
#  'stirring',
#  '</s>',
#  '<s>',
#  'barn',
#  '.',
#  '</s>',
#  '<s>',
#  'well',
#  ',',
#  'goodnight',
#  '.',
#  '</s>',
#  '<s>',
#  'if',
#  'you',
#  'do',
#  'meet',
#  'horatio',
#  'and',
#  'marcellus',
#  ',',
#  'the',
#  'riuals',
#  'of',
#  'my',
#  'watch',
#  ',',
#  'bid',
#  'them',
#  'make',
#  'hast',
#  '.',
#  '</s>',
#  '<s>',
#  'enter',
#  'horatio',
#  'and',
#  'marcellus',
#  '.',
#  '</s>',
#  '<s>',
#  'fran',
#  '.',
#  '</s>',
#  '<s>',
#  'i',
#  'thinke',
#  'i',
#  'heare',
#  'them',
#  '.',
#  '</s>',
#  '<s>',
#  'stand',
#  ':',
#  'who',
#  "'",
#  's',
#  'there',
#  '?',
#  '</s>',
#  '<s>',
#  'hor',
#  '.',
#  '</s>',
#  '<s>',
#  'friends',
#  'to',
#  'this',
#  'ground',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'and',
#  'leige',
#  '-',
#  'men',
#  'to',
#  'the',
#  'dane',
#  '</s>',
#  '<s>',
#  'fran',
#  '.',
#  '</s>',
#  '<s>',
#  'giue',
#  'you',
#  'good',
#  'night',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'o',
#  'farwel',
#  'honest',
#  'soldier',
#  ',',
#  'who',
#  'hath',
#  'relieu',
#  "'",
#  'd',
#  'you',
#  '?',
#  '</s>',
#  '<s>',
#  'fra',
#  '.',
#  '</s>',
#  '<s>',
#  'barnardo',
#  'ha',
#  "'",
#  's',
#  'my',
#  'place',
#  ':',
#  'giue',
#  'you',
#  'goodnight',
#  '.',
#  '</s>',
#  '<s>',
#  'exit',
#  'fran',
#  '.',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'holla',
#  'barnardo',
#  '</s>',
#  '<s>',
#  'bar',
#  '.',
#  '</s>',
#  '<s>',
#  'say',
#  ',',
#  'what',
#  'is',
#  'horatio',
#  'there',
#  '?',
#  '</s>',
#  '<s>',
#  'hor',
#  '.',
#  '</s>',
#  '<s>',
#  'a',
#  'peece',
#  'of',
#  'him',
#  '</s>',
#  '<s>',
#  'bar',
#  '.',
#  '</s>',
#  '<s>',
#  'welcome',
#  'horatio',
#  ',',
#  'welcome',
#  'good',
#  'marcellus',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'what',
#  ',',
#  'ha',
#  "'",
#  's',
#  'this',
#  'thing',
#  'appear',
#  "'",
#  'd',
#  'againe',
#  'to',
#  'night',
#  '</s>',
#  '<s>',
#  'bar',
#  '.',
#  '</s>',
#  '<s>',
#  'i',
#  'haue',
#  'seene',
#  'nothing',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'horatio',
#  'saies',
#  ',',
#  "'",
#  'tis',
#  'but',
#  'our',
#  'fantasie',
#  ',',
#  'and',
#  'will',
#  'not',
#  'let',
#  'beleefe',
#  'take',
#  'hold',
#  'of',
#  'him',
#  'touching',
#  'this',
#  'dreaded',
#  'sight',
#  ',',
#  'twice',
#  'seene',
#  'of',
#  'vs',
#  ',',
#  'therefore',
#  'i',
#  'haue',
#  'intreated',
#  'him',
#  'along',
#  'with',
#  'vs',
#  ',',
#  'to',
#  'watch',
#  'the',
#  'minutes',
#  'of',
#  'this',
#  'night',
#  ',',
#  'that',
#  'if',
#  'againe',
#  'this',
#  'apparition',
#  'come',
#  ',',
#  'he',
#  'may',
#  'approue',
#  'our',
#  'eyes',
#  ',',
#  'and',
#  'speake',
#  'to',
#  'it',
#  '</s>',
#  '<s>',
#  'hor',
#  '.',
#  '</s>',
#  '<s>',
#  'tush',
#  ',',
#  'tush',
#  ',',
#  "'",
#  'twill',
#  'not',
#  'appeare',
#  '</s>',
#  '<s>',
#  'bar',
#  '.',
#  '</s>',
#  '<s>',
#  'sit',
#  'downe',
#  'a',
#  '-',
#  'while',
#  ',',
#  'and',
#  'let',
#  'vs',
#  'once',
#  'againe',
#  'assaile',
#  'your',
#  'eares',
#  ',',
#  'that',
#  'are',
#  'so',
#  'fortified',
#  'against',
#  'our',
#  'story',
#  ',',
#  'what',
#  'we',
#  'two',
#  'nights',
#  'haue',
#  'seene',
#  '</s>',
#  '<s>',
#  'hor',
#  '.',
#  '</s>',
#  '<s>',
#  'well',
#  ',',
#  'sit',
#  'we',
#  'downe',
#  ',',
#  'and',
#  'let',
#  'vs',
#  'heare',
#  'barnardo',
#  'speake',
#  'of',
#  'this',
#  '</s>',
#  '<s>',
#  'barn',
#  '.',
#  '</s>',
#  '<s>',
#  'last',
#  'night',
#  'of',
#  'all',
#  ',',
#  'when',
#  'yond',
#  'same',
#  'starre',
#  'that',
#  "'",
#  's',
#  'westward',
#  'from',
#  'the',
#  'pole',
#  'had',
#  'made',
#  'his',
#  'course',
#  't',
#  "'",
#  'illume',
#  'that',
#  'part',
#  'of',
#  'heauen',
#  'where',
#  'now',
#  'it',
#  'burnes',
#  ',',
#  'marcellus',
#  'and',
#  'my',
#  'selfe',
#  ',',
#  'the',
#  'bell',
#  'then',
#  'beating',
#  'one',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'peace',
#  ',',
#  'breake',
#  'thee',
#  'of',
#  ':',
#  'enter',
#  'the',
#  'ghost',
#  '.',
#  '</s>',
#  '<s>',
#  'looke',
#  'where',
#  'it',
#  'comes',
#  'againe',
#  '</s>',
#  '<s>',
#  'barn',
#  '.',
#  '</s>',
#  '<s>',
#  'in',
#  'the',
#  'same',
#  'figure',
#  ',',
#  'like',
#  'the',
#  'king',
#  'that',
#  "'",
#  's',
#  'dead',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'thou',
#  'art',
#  'a',
#  'scholler',
#  ';',
#  'speake',
#  'to',
#  'it',
#  'horatio',
#  '</s>',
#  '<s>',
#  'barn',
#  '.',
#  '</s>',
#  '<s>',
#  'lookes',
#  'it',
#  'not',
#  'like',
#  'the',
#  'king',
#  '?',
#  '</s>',
#  '<s>',
#  'marke',
#  'it',
#  'horatio',
#  '</s>',
#  '<s>',
#  'hora',
#  '.',
#  '</s>',
#  '<s>',
#  'most',
#  'like',
#  ':',
#  'it',
#  'harrowes',
#  'me',
#  'with',
#  'fear',
#  '&',
#  'wonder',
#  'barn',
#  '.',
#  '</s>',
#  '<s>',
#  'it',
#  'would',
#  'be',
#  'spoke',
#  'too',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'question',
#  'it',
#  'horatio',
#  '</s>',
#  '<s>',
#  'hor',
#  '.',
#  '</s>',
#  '<s>',
#  'what',
#  'art',
#  'thou',
#  'that',
#  'vsurp',
#  "'",
#  'st',
#  'this',
#  'time',
#  'of',
#  'night',
#  ',',
#  'together',
#  'with',
#  'that',
#  'faire',
#  'and',
#  'warlike',
#  'forme',
#  'in',
#  'which',
#  'the',
#  'maiesty',
#  'of',
#  'buried',
#  'denmarke',
#  'did',
#  'sometimes',
#  'march',
#  ':',
#  'by',
#  'heauen',
#  'i',
#  'charge',
#  'thee',
#  'speake',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'it',
#  'is',
#  'offended',
#  '</s>',
#  '<s>',
#  'barn',
#  '.',
#  '</s>',
#  '<s>',
#  'see',
#  ',',
#  'it',
#  'stalkes',
#  'away',
#  '</s>',
#  '<s>',
#  'hor',
#  '.',
#  '</s>',
#  '<s>',
#  'stay',
#  ':',
#  'speake',
#  ';',
#  'speake',
#  ':',
#  'i',
#  'charge',
#  'thee',
#  ',',
#  'speake',
#  '.',
#  '</s>',
#  '<s>',
#  'exit',
#  'the',
#  'ghost',
#  '.',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  "'",
#  'tis',
#  'gone',
#  ',',
#  'and',
#  'will',
#  'not',
#  'answer',
#  '</s>',
#  '<s>',
#  'barn',
#  '.',
#  '</s>',
#  '<s>',
#  'how',
#  'now',
#  'horatio',
#  '?',
#  '</s>',
#  '<s>',
#  'you',
#  'tremble',
#  '&',
#  'look',
#  'pale',
#  ':',
#  'is',
#  'not',
#  'this',
#  'something',
#  'more',
#  'then',
#  'fantasie',
#  '?',
#  '</s>',
#  '<s>',
#  'what',
#  'thinke',
#  'you',
#  'on',
#  "'",
#  't',
#  '?',
#  '</s>',
#  '<s>',
#  'hor',
#  '.',
#  '</s>',
#  '<s>',
#  'before',
#  'my',
#  'god',
#  ',',
#  'i',
#  'might',
#  'not',
#  'this',
#  'beleeue',
#  'without',
#  'the',
#  'sensible',
#  'and',
#  'true',
#  'auouch',
#  'of',
#  'mine',
#  'owne',
#  'eyes',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'is',
#  'it',
#  'not',
#  'like',
#  'the',
#  'king',
#  '?',
#  '</s>',
#  '<s>',
#  'hor',
#  '.',
#  '</s>',
#  '<s>',
#  'as',
#  'thou',
#  'art',
#  'to',
#  'thy',
#  'selfe',
#  ',',
#  'such',
#  'was',
#  'the',
#  'very',
#  'armour',
#  'he',
#  'had',
#  'on',
#  ',',
#  'when',
#  'th',
#  "'",
#  'ambitious',
#  'norwey',
#  'combatted',
#  ':',
#  'so',
#  'frown',
#  "'",
#  'd',
#  'he',
#  'once',
#  ',',
#  'when',
#  'in',
#  'an',
#  'angry',
#  'parle',
#  'he',
#  'smot',
#  'the',
#  'sledded',
#  'pollax',
#  'on',
#  'the',
#  'ice',
#  '.',
#  '</s>',
#  '<s>',
#  "'",
#  'tis',
#  'strange',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'thus',
#  'twice',
#  'before',
#  ',',
#  'and',
#  'iust',
#  'at',
#  'this',
#  'dead',
#  'houre',
#  ',',
#  'with',
#  'martiall',
#  'stalke',
#  ',',
#  'hath',
#  'he',
#  'gone',
#  'by',
#  'our',
#  'watch',
#  '</s>',
#  '<s>',
#  'hor',
#  '.',
#  '</s>',
#  '<s>',
#  'in',
#  'what',
#  'particular',
#  'thought',
#  'to',
#  'work',
#  ',',
#  'i',
#  'know',
#  'not',
#  ':',
#  'but',
#  'in',
#  'the',
#  'grosse',
#  'and',
#  'scope',
#  'of',
#  'my',
#  'opinion',
#  ',',
#  'this',
#  'boades',
#  'some',
#  'strange',
#  'erruption',
#  'to',
#  'our',
#  'state',
#  '</s>',
#  '<s>',
#  'mar',
#  '.',
#  '</s>',
#  '<s>',
#  'good',
#  'now',
#  'sit',
#  'downe',
#  ',',
#  '&',
#  'tell',
#  'me',
#  'he',
#  'that',
#  'knowes',
#  'why',
#  'this',
#  'same',
#  'strict',
#  'and',
#  'most',
#  'obseruant',
#  'watch',
#  ',',
#  'so',
#  'nightly',
#  'toyles',
#  'the',
#  'subiect',
#  'of',
#  'the',
#  'land',
#  ',',
#  'and',
#  'why',
#  'such',
#  'dayly',
#  'cast',
#  'of',
#  'brazon',
#  'cannon',
#  'and',
#  'forraigne',
#  'mart',
#  'for',
#  'implements',
#  'of',
#  'warre',
#  ':',
#  'why',
#  'such',
#  'impresse',
#  'of',
#  'ship',
#  '-',
#  ...]

# %% [markdown]
# **Note:** lazy iterators (aka generators) is for one-use only.

# %%
padded_ngrams, flat_text = padded_everygram_pipeline(2, ['winter is coming'.split()])
print(padded_ngrams)
print([list(x) for x in padded_ngrams]) # We use the generator
print([list(x) for x in padded_ngrams]) # We lose it 
# If you want to reuse the generator you have to recompute it
padded_ngrams, flat_text = padded_everygram_pipeline(2, ['winter is coming'.split()])
print([list(x) for x in padded_ngrams])

# %% [markdown]
# ### 1.2. Ngram Counter
# NLTK provides NgramCounter class to do the ngram counting. The class can be initialized without any agrument and then updated with ngrams (via `update()` method); or directly initialized with ngrams.
#
# `N()` method returns total number of ngrams stored.

# %%
from nltk.lm import NgramCounter

counter = NgramCounter()
counter.N()  # return total number of stored ngrams

# %%
padded_ngrams, flat_text = padded_everygram_pipeline(2, data)
counter.update(padded_ngrams)  # update counter with ngrams
counter.N()

# %%
padded_ngrams, flat_text = padded_everygram_pipeline(2, data)
counter = NgramCounter(padded_ngrams)
counter.N()

# %% [markdown]
# #### 1.2.1. Accessing Ngram Counts
#
# Ngram counts can be accessed using standard python dictionary notation.
# - Ngram order counts can be accessed using integer keys (order)
#     - returns `Frequency Distribution` or `Conditional Frequency Distribution` objects. [link](https://www.nltk.org/api/nltk.probability.html)
# - Unigram counts can be accessed using string keys.
# - Bigram counts can be accessed using list keys & string keys (see example)

# %%
# ngram order counts
print(counter[1])  # Frequency Distribution
print(counter[2])  # Conditional Frequency Distribution

# %%
# print counts
print(counter.unigrams)  # unigram count for convenience

# %%
# unigram counts
counter['the']

# %%
# 'full' bigram counts (full bigrams)
counter[['the']]['answer']

# %%
# to get a frequency distribution over all continuations, you can use list or tuple. 
# counter[['the']] or counter[('the',)]
counter[['the']]

# %%
# For Conditional Frequency Distributions, only tuples are accepted.
# counter[2][['the']] will throw an error
counter[2][('answer',)]

# %% [markdown]
# ### Exercise: Counting Ngrams in Shakespeare's Hamlet
#
# - Load Shakespeare's Hamlet from Gutenberg corpus
#     - lowercase it
#
# - Extract padded unigrams and bigrams
#
# - Using NgramCounter
#     - get total number of ngrams
#     - get count of unigram `the`
#     - get count of bigram `of the`
#
# |                     | Count  |
# |---------------------|---------|
# | Ngrams      | 84038     |
# | Unigram *the* | 993|
# | Bigram *of the*     |59 |

# %%
from nltk.corpus import gutenberg

hamlet = gutenberg.sents('shakespeare-hamlet.txt')

print(len(hamlet))
print(hamlet[0])
# lowercasing use .lower()
hamlet_lowercase = [[w.lower() for w in sent] for sent in hamlet]
print(hamlet_lowercase[0])

# %%
padded_ngrams, flat_text = padded_everygram_pipeline(2, hamlet_lowercase)

# %%
counter = NgramCounter(padded_ngrams)

# %%
print(counter.N())
print(counter['the'])
print(counter[['of']]['the'])

# %% [markdown]
# ## 2. Vocabulary and Basic Usage

# %% [markdown]
# [`Vocabulary`](https://www.nltk.org/api/nltk.lm.vocabulary.html) class of NLTK satisfies two common language modeling requirements for a vocabulary:
# - When checking membership and calculating its size, filters items by comparing their counts to a cutoff value.
# - Adds a special "unknown" token which unseen words are mapped to.
#
# Tokens with counts greater than or equal to the cut-off value will be considered part of the vocabulary.

# %% [markdown]
# `Vocabulary(counts=None, unk_cutoff=1, unk_label='<UNK>)` create a new `Vocabulary`.
#
# - `counts` (optional) iterable or collections.
#     - Counter instance to pre-seed the `Vocabulary`.
#     - In case it is iterable, counts are calculated.
#
# - `unk_cutoff` (int) - Words that occur less frequently than this value are not considered part of the vocabulary.
#
# - `unk_label` - Label for marking words not part of vocabulary.

# %%
from nltk.lm import Vocabulary
from nltk.corpus import gutenberg

hamlet_words = gutenberg.words('shakespeare-hamlet.txt')

# lowercase
hamlet_words = [w.lower() for w in hamlet_words]

# initialize vocabulary with cut-off
vocab = Vocabulary(hamlet_words, unk_cutoff=2)

# %% [markdown]
# `Vocabulary` methods:
#
# - `lookup()` looks up words in a vocabulary.
#     - "Unseen" words (with counts less than cutoff) are looked up as the unknown label.
#     - If given one word (a string) as an input, this method will return a string.
#     - If given a sequence, it will return an tuple of the looked up words.
#
# - `update()` update counts from a sequence

# %% [markdown]
# `Vocabulary` properties:
#
# - `cutoff` - same as `unk_cutoff`
#
# - `unk_label` and `counts` can also be accessed as properties
#     - `vocab.unk_label`
#     - `vocab.counts`

# %% [markdown]
# ### 2.1. Counts, Vocabulary Membership, and Lookup
#
# Tokens with frequency counts less than the `cutoff` value will be considered not part of the vocabular, even though their entries in the count dictionary are preserved.
#
# This is useful for changing cut-off without recomputing counts.

# %%
# let's define a function to illustrate the relation between counts, membership, and lookup
def test_word(word, vocab):
    # let's lowercase it
    if word != vocab.unk_label:
        word = word.lower() 
    # membership test
    word_membership = word in vocab
    # accessing count
    word_count = vocab[word]
    # lookup
    word_lookup = vocab.lookup(word)
    
    print("Word: '{}', Count: {}, In Vocab: {}, Mapped to: '{}'".format(
        word, word_count, word_membership, word_lookup))

# %%
for w in ["<UNK>", "the", "1599", "Trento"]:
    test_word(w, vocab)

# %% [markdown]
# ### 2.2. Cut-Off and Vocabulary Size
# The cut-off value influences not only membership checking but also the result of getting the size of the vocabulary using the built-in `len`. Note that while the number of keys in the vocabulary's counter stays the same, the items in the vocabulary differ depending on the cut-off.

# %%
# Let's define another vocabulary with cut-off 1
# Notice that we are passing counts from the original vocabulary
vocab1 = Vocabulary(vocab.counts, unk_cutoff=1)

# %%
print("CutOff 2:", len(vocab))
print("CutOff 1:", len(vocab1))

# %%
print("CutOff 2 Counts:", len(vocab.counts))
print("CutOff 1 Counts:", len(vocab1.counts))

# %% [markdown]
# #### Exercise
# - lookup in vocabulary
#     - "trento is the capital city of trentino"
# - update vocabulary with "trento is the capital city of trentino"
#     - do the lookup again to see the effect
# - experiment with changing the cut-off value from `1` to `10`
#     - do the lookup again to see the effect

# %%
sentence = "trento is the capital city of trentino".split()

# Cut-off 0   
vocab = Vocabulary(hamlet_words)
print(list(vocab.lookup(sentence)))
vocab.update(sentence)
print(list(vocab.lookup(sentence)))

# %%
# Cut-off 1
vocab = Vocabulary(hamlet_words, unk_cutoff=1)
print(list(vocab.lookup(sentence)))
vocab.update(sentence)
print(list(vocab.lookup(sentence)))

# Cut-off 10
vocab = Vocabulary(hamlet_words, unk_cutoff=10)
print(list(vocab.lookup(sentence)))
vocab.update(sentence)
print(list(vocab.lookup(sentence)))

# %% [markdown]
# ## 3. Training Language Model

# %% [markdown]
# Using the data prepared as we have seen above, the `NLTK` ngram model boils down to counting ngrams, as presented above, by specifying the highest ngram size order.

# %%
# Let's prepare data on hamlet
from nltk.lm.preprocessing import padded_everygram_pipeline
data = [[w.lower() for w in sent] for sent in gutenberg.sents('shakespeare-hamlet.txt')]
padded_ngrams, flat_text = padded_everygram_pipeline(2, data)

# %%
# Let's train a `Maximum Likelihood Estimator (MLE)
from nltk.lm import MLE
mle_lm = MLE(2) # Where 2 is the highest N-gram size order

# %% [markdown]
# Initialization of the Language Model creates:
# - empty vocabulary
# - empty counts
#
# These are populated once we `fit` the model with training data.

# %%
# .vocab refers to the Vocabulary class that we have seen before
print(mle_lm.vocab)
# .vocab refers to the NgramCounter class that we have seen before
print(mle_lm.counts)
# Out:
# <Vocabulary with cutoff=1 unk_label='<UNK>' and 0 items>
# <NgramCounter with 1 ngram orders and 0 ngrams>

# %%
mle_lm.fit(padded_ngrams, flat_text)

# %%
print(mle_lm.vocab)
print(mle_lm.counts)
# Out:
# <Vocabulary with cutoff=1 unk_label='<UNK>' and 4719 items>
# <NgramCounter with 2 ngram orders and 84038 ngrams>

# %% [markdown]
# ## 4. Using Ngram Language Models
#
# A statistical [language model](https://en.wikipedia.org/wiki/Language_model) is a probability distribution over sequences of words. Given such a sequence, say of length $n$, it assigns a probability $P(w_{1},\ldots ,w_{n})$ ($P(w_{1}^{n})$, for compactness) to the whole sequence (using Chain Rule). Consequently, the unigram and bigram probabilities computed above constitute an ngram language model of our corpus.
#
# <!-- It is more useful for Natural Language Processing to have a __probability__ of a sequence being legal, rather than a grammar's __boolean__ decision whether it is legal or not. -->

# %% [markdown]
# ### 4.1. Computing Probability of a Sequence (Scoring)
#
# The most common usage of a language model is to compute probability of a sequence.

# %% [markdown]
# #### Probability of a Sequence
#
# Probability of a sequence is computed as a product of conditional probabilities ([Chain Rule](https://en.wikipedia.org/wiki/Chain_rule_(probability))).
#
# $$P(w_{1}^{n}) = P(w_1) P(w_2|w_1) P(w_3|w_1^2) ... P(w_n|w_{1}^{n-1}) = \prod_{i=1}^{n}{P(w_i|w_{1}^{i-1})}$$
#
# The order of ngram makes a simplifying assumption that probability of a current word only depends on previous $N - 1$ elements. Thus, it truncates previous context (history) to length $N - 1$.
#
# $$P(w_i|w_{1}^{i-1}) \approx P(w_i|w_{i-N+1}^{i-1})$$
#
# Consequently we have:
#
# N-gram   | Equation                   |
# :--------|:---------------------------|
# unigram  | $$P(w_i)$$                 |
# bigram   | $$P(w_i|w_{i-1})$$         |
# trigram  | $$P(w_i|w_{i-2},w_{i-1})$$ |
#
# The probability of the whole sequence applying an ngram model becomes:
#
# $$P(w_{1}^{n}) = \prod_{i=1}^{n}{P(w_i|w_{i-N+1}^{i-1})}$$

# %% [markdown]
# #### Calculating Probability from Frequencies
#
# Probabilities of ngrams can be computed *normalizing* frequency counts (*Maximum Likelihood Estimation*): dividing the frequency of an ngram sequence by the frequency of its prefix (*relative frequency*).
#
# N-gram   | Equation
# :--------|:------------------------------
# Unigram  | $$p(w_i) = \frac{c(w_i)}{N}$$
# Bigram   | $$p(w_i | w_{i-1}) = \frac{c(w_{i-1}, w_i)}{c(w_{i-1})}$$
# Ngram    | $$p(w_i | w_{i-n+1}^{i-1}) = \frac{c(w_{i-n+1}^{i-1}, w_i)}{c(w_{i-n+1}^{i-1})}$$
#
# where:
# - $N$ is the total number of words in a corpus
# - $c(x)$ is the count of occurrences of $x$ in a corpus (x could be unigram, bigram, etc.)

# %% [markdown]
# #### 4.1.1. Scoring Methods of NLTK LMs
# - `score(word, context=None)` Masks out of vocab (OOV) words (i.e. maps them to `<UNK>`) and computes their model score.
#     - scores are **model-specific** (later on this)
#     - Parameters:
#         - `word (str)` - Word for which we want the score
#         - `context (tuple(str))` - Context the word is in. If None, computes unigram score.
#
# - `logscore(word, context=None)` - Evaluate the log score of this word in this context.

# %%
# A little illustration of the methods
mle_lm.score("the")
# Out:
# 0.02278986505095015

# %%
mle_lm.score("the", ["of"])
# Out:
# 0.09672131147540984

# %%
mle_lm.logscore("the", ["of"]) # == math.log(mle_lm.score("the", ["of"]), 2) log base 2
# Out:
# -3.3700223830884077

# %% [markdown]
# #### Exercise
# Implement a function to compute score of a sequence (i.e. Chain Rule)
#
# - arguments:
#     - Language Model
#     - List of Tokens
#
# - functionality
#     - extracts ngrams w.r.t. LM order (`lm.order`)
#     - scores each ngram w.r.t. LM (`lm.score` or `lm.logscore`)
#         - mind that `score` takes care of OOV by conterting to `<UNK>` already
#     - computes the overal score using chain rule
#         - mind the difference between `score` and `logscore`
#
# - compute the scores of the sentences below
#     - compute padded and unpadded sequence scores

# %%
test_sents = ["the king is dead", "the tzar is dead", 'the tragedie of hamlet is good']

# %%
from itertools import chain
def chain_rule(lm, sentence, log=True, pad=True):
    highest_ngram = lm.order
    tokens = sentence.split()
    if pad:
        ngrams, flat_text = padded_everygram_pipeline(highest_ngram, [tokens])
        ngrams = chain.from_iterable(ngrams) # Flat the sequence
    else:
        ngrams = everygrams(tokens, max_len=highest_ngram)
        flat_text = tokens
        
    if log:
        total_score = 0
    else:
        total_score = 1
        
    for x in ngrams:
        if len(x) == highest_ngram:
            if log:
                w_t = x[-1]
                # In python you can get a split of a tuple or array as array[from:to] "to" is excluded
                context = x[0:-1] # or x[:-1]
                score = lm.logscore(w_t, context)
                total_score += score # Add or multiply score to total_score ?
            else:
                w_t = x[-1]
                context = x[0:-1]
                score = lm.score(w_t, context)
                total_score *= score
    
    return total_score

for sent in test_sents:
    print(sent, chain_rule(mle_lm, sent, log=True, pad=True))
# Out:
# the king is dead -25.988633342954444
# the tzar is dead -inf
# the tragedie of hamlet is good -40.90367505315022

# %% [markdown]
# #### 4.1.2. OOV in MLE
# In MLE LM we did not take care of OOV. Consequently, those have `0` counts and probabilities.

# %%
print(mle_lm.score("<UNK>"))
print(mle_lm.score("<UNK>", ["<UNK>"]))
print(mle_lm.score("<UNK>", ["the"]))
# Out:
# 0.0
# 0
# 0.0

# %%
# same as above: getting lowercaseed sentences and words 
hamlet_sents = [[w.lower() for w in sent] for sent in gutenberg.sents('shakespeare-hamlet.txt')]
print(hamlet_sents)
hamlet_words = flatten(hamlet_sents)
# Out:
# [['[', 'the', 'tragedie', 'of', 'hamlet', 'by', 'william', 'shakespeare', '1599', ']'], ['actus', 'primus', '.'], ['scoena', 'prima', '.'], ['enter', 'barnardo', 'and', 'francisco', 'two', 'centinels', '.'], ['barnardo', '.'], ['who', "'", 's', 'there', '?'], ['fran', '.'], ['nay', 'answer', 'me', ':', 'stand', '&', 'vnfold', 'your', 'selfe'], ['bar', '.'], ['long', 'liue', 'the', 'king'], ['fran', '.'], ['barnardo', '?'], ['bar', '.'], ['he'], ['fran', '.'], ['you', 'come', 'most', 'carefully', 'vpon', 'your', 'houre'], ['bar', '.'], ["'", 'tis', 'now', 'strook', 'twelue', ',', 'get', 'thee', 'to', 'bed', 'francisco'], ['fran', '.'], ['for', 'this', 'releefe', 'much', 'thankes', ':', "'", 'tis', 'bitter', 'cold', ',', 'and', 'i', 'am', 'sicke', 'at', 'heart'], ['barn', '.'], ['haue', 'you', 'had', 'quiet', 'guard', '?'], ['fran', '.'], ['not', 'a', 'mouse', 'stirring'], ['barn', '.'], ['well', ',', 'goodnight', '.'], ['if', 'you', 'do', 'meet', 'horatio', 'and', 'marcellus', ',', 'the', 'riuals', 'of', 'my', 'watch', ',', 'bid', 'them', 'make', 'hast', '.'], ['enter', 'horatio', 'and', 'marcellus', '.'], ['fran', '.'], ['i', 'thinke', 'i', 'heare', 'them', '.'], ['stand', ':', 'who', "'", 's', 'there', '?'], ['hor', '.'], ['friends', 'to', 'this', 'ground'], ['mar', '.'], ['and', 'leige', '-', 'men', 'to', 'the', 'dane'], ['fran', '.'], ['giue', 'you', 'good', 'night'], ['mar', '.'], ['o', 'farwel', 'honest', 'soldier', ',', 'who', 'hath', 'relieu', "'", 'd', 'you', '?'], ['fra', '.'], ['barnardo', 'ha', "'", 's', 'my', 'place', ':', 'giue', 'you', 'goodnight', '.'], ['exit', 'fran', '.'], ['mar', '.'], ['holla', 'barnardo'], ['bar', '.'], ['say', ',', 'what', 'is', 'horatio', 'there', '?'], ['hor', '.'], ['a', 'peece', 'of', 'him'], ['bar', '.'], ['welcome', 'horatio', ',', 'welcome', 'good', 'marcellus'], ['mar', '.'], ['what', ',', 'ha', "'", 's', 'this', 'thing', 'appear', "'", 'd', 'againe', 'to', 'night'], ['bar', '.'], ['i', 'haue', 'seene', 'nothing'], ['mar', '.'], ['horatio', 'saies', ',', "'", 'tis', 'but', 'our', 'fantasie', ',', 'and', 'will', 'not', 'let', 'beleefe', 'take', 'hold', 'of', 'him', 'touching', 'this', 'dreaded', 'sight', ',', 'twice', 'seene', 'of', 'vs', ',', 'therefore', 'i', 'haue', 'intreated', 'him', 'along', 'with', 'vs', ',', 'to', 'watch', 'the', 'minutes', 'of', 'this', 'night', ',', 'that', 'if', 'againe', 'this', 'apparition', 'come', ',', 'he', 'may', 'approue', 'our', 'eyes', ',', 'and', 'speake', 'to', 'it'], ['hor', '.'], ['tush', ',', 'tush', ',', "'", 'twill', 'not', 'appeare'], ['bar', '.'], ['sit', 'downe', 'a', '-', 'while', ',', 'and', 'let', 'vs', 'once', 'againe', 'assaile', 'your', 'eares', ',', 'that', 'are', 'so', 'fortified', 'against', 'our', 'story', ',', 'what', 'we', 'two', 'nights', 'haue', 'seene'], ['hor', '.'], ['well', ',', 'sit', 'we', 'downe', ',', 'and', 'let', 'vs', 'heare', 'barnardo', 'speake', 'of', 'this'], ['barn', '.'], ['last', 'night', 'of', 'all', ',', 'when', 'yond', 'same', 'starre', 'that', "'", 's', 'westward', 'from', 'the', 'pole', 'had', 'made', 'his', 'course', 't', "'", 'illume', 'that', 'part', 'of', 'heauen', 'where', 'now', 'it', 'burnes', ',', 'marcellus', 'and', 'my', 'selfe', ',', 'the', 'bell', 'then', 'beating', 'one'], ['mar', '.'], ['peace', ',', 'breake', 'thee', 'of', ':', 'enter', 'the', 'ghost', '.'], ['looke', 'where', 'it', 'comes', 'againe'], ['barn', '.'], ['in', 'the', 'same', 'figure', ',', 'like', 'the', 'king', 'that', "'", 's', 'dead'], ['mar', '.'], ['thou', 'art', 'a', 'scholler', ';', 'speake', 'to', 'it', 'horatio'], ['barn', '.'], ['lookes', 'it', 'not', 'like', 'the', 'king', '?'], ['marke', 'it', 'horatio'], ['hora', '.'], ['most', 'like', ':', 'it', 'harrowes', 'me', 'with', 'fear', '&', 'wonder', 'barn', '.'], ['it', 'would', 'be', 'spoke', 'too'], ['mar', '.'], ['question', 'it', 'horatio'], ['hor', '.'], ['what', 'art', 'thou', 'that', 'vsurp', "'", 'st', 'this', 'time', 'of', 'night', ',', 'together', 'with ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-d6b4bab509a9> in <module>
#       2 hamlet_sents = [[w.lower() for w in sent] for sent in gutenberg.sents('shakespeare-hamlet.txt')]
#       3 print(hamlet_sents)
# ----> 4 hamlet_words = flatten(hamlet_sents)
#
# NameError: name 'flatten' is not defined

# %%
# computing vocabulary with cutoff
lex = Vocabulary(hamlet_words, unk_cutoff=2)
print(len(lex))
# Out:
# 1867

# %%
# replacing words with counts below cutoff with '<UNK>'
hamlet_oov_sents = [list(lex.lookup(sent)) for sent in hamlet_sents]
print(hamlet_oov_sents[0])
# Out:
# ['[', 'the', 'tragedie', 'of', 'hamlet', 'by', '<UNK>', '<UNK>', '<UNK>', ']']

# %%
# extracting ngrams & words again
padded_ngrams_oov, flat_text_oov = padded_everygram_pipeline(2, hamlet_oov_sents)

# %%
lm_oov = MLE(2)
lm_oov.fit(padded_ngrams_oov, flat_text_oov)

# %%
print(lm_oov.score("<UNK>"))
print(lm_oov.score("<UNK>", ["<UNK>"]))
print(lm_oov.score("<UNK>", ["the"]))
# Out:
# 0.06540897824290828
# 0.06842105263157895
# 0.24874118831822759

# %% [markdown]
# #### 4.1.3. Data Sparsity: Missing Ngrams
# However, even though we have counted ngrams on the data set with `<UNK>`, the counts still do not account for all possible ngrams. Thus, some possible sequences will have zero probability.
#
# __We will address this later.__

# %%
print(lm_oov.score("queen"))
print(lm_oov.score("<UNK>", ["queen"]))
print(lm_oov.score("queen", ["<UNK>"]))
# Out:
# 0.00018360414945377767
# 0.0
# 0.0

# %% [markdown]
# ### 4.2. Generating Sequences
#
# Ngram Model can be used as an automaton to generate probable legal sequences using the algorithm below.
#
# __Algorithm for Bigram LM__
#
# - $w_{i-1} = $ `<s>`;
# - *while* $w_i \neq $ `</s>`
#
#     - stochastically get new word w.r.t. $P(w_i|w_{i-1})$

# %% [markdown]
# #### 4.2.1. Generation Method of NLTK LM
# - `generate(num_words=1, text_seed=None, random_seed=None)` generates words from the model.
#     - Parameters
#         - `num_words (int)` - How many words to generate. By default 1.
#         - `text_seed` - preceding context the generation should be conditioned on.
#             - ngram model is restricted in how much preceding context it can take into account based on max ngram size
#         - `random_seed` - A random seed. If provided, makes the random sampling part of generation reproducible.

# %%
mle_lm.generate(5)

# %%
mle_lm.generate(5, text_seed=['hamlet'])

# %% [markdown]
# ### 4.3. Language Model Evaluation
#
# Language Models are evaluated using [Perplexity](https://en.wikipedia.org/wiki/Perplexity)
#
# - Measures how well model fits test data
# - Probability of test data
# - Weighted average branching factor in predicting the next word (lower is better).
# - Computed as:
#
# $$ PP(W) = \sqrt[N]{\frac{1}{P(w_1,w_2,...,w_N)}} = \sqrt[N]{\frac{1}{\prod_{i=1}^{N}P(w_i|w_{i-N+1})}}$$
#
# Where $N$ is the number of words in test set.

# %% [markdown]
# #### 4.3.1. Evaluation Methods of NLTK LM

# %% [markdown]
# `NLTK` provides both **perplexity** and **cross-entropy** as evaluation methods
#
# - `entropy(text_ngrams)` calculates cross-entropy of model for given evaluation text.
#     - Parameters
#         - `text_ngrams (Iterable(tuple(str)))` A sequence of ngram tuples.
#
# - `perplexity(text_ngrams)` calculates the perplexity of the given text.
#     - This is _2 ** cross-entropy_ for the text, so the arguments are the same.

# %% [markdown]
# **Perplexity** is related to [**Cross-Entropy**](https://en.wikipedia.org/wiki/Cross_entropy) as:
#
# $$PP(p) = 2^{H(p)}$$ (abbreviated as PPL also)

# %% [markdown]
# #### Exercise
# Compute entropy and perplexity of the `MLE` models  on the bigrams of the test sentences below, treating them as a test set.
#
# - experiment with the two test sets
# - experiment with OOVs (with vs without)

# %%
test_sents1 = ["the king is dead", "the emperor is dead", "may the force be with you"]
test_sents2 = ["the king is dead", "welcome to you", "how are you"]

# %%
# Load data
hamlet_sents = [[w.lower() for w in sent] for sent in gutenberg.sents('shakespeare-hamlet.txt')]
hamlet_words = flatten(hamlet_sents)
# Compute vocab 
lex = Vocabulary(hamlet_words, unk_cutoff=2)
# Handeling OOV
hamlet_oov_sents = [list(lex.lookup(sent)) for sent in hamlet_sents]
padded_ngrams_oov, flat_text_oov = padded_everygram_pipeline(2, hamlet_oov_sents)
# Train the model 
lm_oov = MLE(2)
lm_oov.fit(padded_ngrams_oov, flat_text_oov)
# Compute PPL and entropu with OOV on test 1
test_set = test_sents2
ngrams, flat_text = padded_everygram_pipeline(lm_oov.order, [lex.lookup(sent.split()) for sent in test_set])
ngrams = chain.from_iterable(ngrams)
ppl =  lm_oov.perplexity([x for x in ngrams   if len(x) == lm_oov.order])
print('PPL:', ppl)
# Generators are one-use only!
ngrams, flat_text = padded_everygram_pipeline(lm_oov.order, [lex.lookup(sent.split()) for sent in test_set])
ngrams = chain.from_iterable(ngrams)
cross_entropy = lm_oov.entropy([x for x in ngrams  if len(x) == lm_oov.order])
print('Cross Entropy :', cross_entropy)
print('\t PPL:', pow(2, cross_entropy))
# Out:
# PPL: 231.41287894467075
# Cross Entropy : 7.854325347532861
# 	 PPL: 231.41287894467075

# %% [markdown]
# ##### PP: how it works inside

# %%
import math
import numpy as np

def compute_ppl(model, data):
    highest_ngram = model.order
    scores = [] 
    for sentence in data:
        ngrams, flat_text = padded_everygram_pipeline(highest_ngram, [sentence.split()])
        scores.extend([model.logscore(w[-1], w[:-1]) for gen in ngrams for w in gen if len(w) == highest_ngram])
    
    return math.pow(2.0, (-1 * np.asarray(scores).mean()))
compute_pp(mle_lm, test_sents2)
# Out:
# 49.091034440830974

# %% [markdown]
# ### 4.4. Handling Data Sparseness: Smoothing in NLTK

# %% [markdown]
# [`Smoothing(vocabulary, counter, **kwargs)`](https://www.nltk.org/api/nltk.lm.smoothing.html) Class is initialized with the following parameters:
#
# - `vocabulary (nltk.lm.vocab.Vocabulary)` - The Ngram vocabulary object.
# - `counter (nltk.lm.counter.NgramCounter)` - The counts of the vocabulary items.

# %% [markdown]
# `Ngram Smoothing Interface` implements [Chen & Goodman 1995](https://aclanthology.org/P96-1041.pdf)'s idea that all smoothing algorithms have certain features in common. Consequently, each Smoothing subclass implements two methods:
#
# - `unigram_score(word)` return unigram score
# - `alpha_gamma(word, context)` returns alpha and gamma values (varies w.r.t. method)
#     - `gamma` is the value added to missing ngram count
#     - `alpha` is the value used to scale the lower order probabilities

# %% [markdown]
# The following smoothing methods are implemented:
# - `WittenBell(vocabulary, counter, **kwargs)` - Witten-Bell smoothing
#
# - `AbsoluteDiscounting(vocabulary, counter, discount=0.75, **kwargs)` - Smoothing with absolute discount
#     - takes `discount=0.75` parameter (default 0.75)
#
# - `KneserNey(vocabulary, counter, order, discount=0.1, **kwargs)` - Kneser-Ney Smoothing (an extension of smoothing with a discount)

# %% [markdown]
# ### 4.5. NLTK Language Models
#
# All the language models in NLTK share the same interface and share methods for
# - evaluation
# - generation
# - scoring

# %% [markdown]
# **Scoring** in a language model does the following:
# - takes care of OOV words (see above)
# - computes `unmasked_score`
#
# The way `unmasked_score` is computed from counts is the difference.

# %% [markdown]
# Some langauge models use **smoothing** to account for missing ngrams, some do not (e.g. `MLE`)

# %% [markdown]
# Available LM Implementations
#
# - `MLE` - providing MLE ngram model scores.
#
# - Additive Smoothing LMs
#     - `Laplace` - Laplace (add one) smoothing ($\gamma = 1$)
#     - `Lidstone` - same as `Laplace`, but adds $\gamma$
#
# - Back-Off Language Models
#     - `StupidBackoff` - uses `alpha` to scale the lower order probabilities for computing missing ngram scores
#
# - Interpolated Language Models
#     - `WittenBellInterpolated` - Interpolated version of Witten-Bell smoothing
#     - `KneserNeyInterpolated` - Interpolated version of Kneser-Ney smoothing.
#     - `AbsoluteDiscountingInterpolated` - Interpolated version of smoothing with absolute discount

# %% [markdown]
# ## Lab Exercise: Language Model Evaluation
# Write your own implementation of the Stupid backoff algorithm. Train it and compare the perplexity with the one provided by NLKT. The dataset that you have to use is the *Shakespeare Macbeth*.
#
# Stupid Backoff algorithm (use ⍺=0.4):
# https://aclanthology.org/D07-1090.pdf
#
# NLTK (StupidBackoff):
# https://www.nltk.org/api/nltk.lm.html
#
# **Suggestion**: adapt the `compute_ppl` function to compute the perplexity of your model. The PPL has to be computed on the whole corpus and not at sentence level.

# %%
# NLTK StupidBackoff
from nltk.lm import StupidBackoff
# Dataset
macbeth_sents = [[w.lower() for w in sent] for sent in gutenberg.sents('shakespeare-macbeth.txt')]
